# %% [markdown]
# # Merge facility information
#
# Merge facility data from these 3 sources:
# - HCRIS (Healthcare Cost Reporting Information System)
# - HIFLD (Homeland Infrastructure Foundation-Level Data)
# - DH (Definitive Healthcare)

# %%
import pandas as pd
import geopandas as gpd

from hscap.geo import spatial_join_facilities

# %%
hcris_gdf = gpd.read_file('../data/usa_hospital_beds_hcris2018_v2.geojson', encoding='utf-8')
hifld_gdf = gpd.read_file('../data/hifld_facility_data.geojson', encoding='utf-8')
dh_gdf = gpd.read_file('../data/dh_facility_data.geojson', encoding='utf-8')

# %% [markdown]
# ## Filter facilities with unusable data.

# %%
dh_gdf = dh_gdf[~dh_gdf['geometry'].isna()]
hifld_gdf = hifld_gdf[hifld_gdf['BEDS'] > 0]
hcris_gdf = hcris_gdf[hcris_gdf['Total Staffed Beds'] > 0.0]

# %% [markdown]
# Perform the matching on facilities based on a spatial join and similarity score between address and name columns.

# %%
id_columns = {
    'HCRIS': 'Provider Number',
    'HIFLD': 'ID',
    'DH': 'OBJECTID'
}

similarity_columns = {
    'HCRIS': ['HOSP10_Name', 'Street_Addr'],
    'HIFLD': ['NAME', 'ADDRESS'],
    'DH': ['HOSPITAL_N', 'HQ_ADDRESS']
}

# %%
hcris_filtered_gdf = hcris_gdf[['geometry', id_columns['HCRIS']] + similarity_columns['HCRIS']]
hifld_filtered_gdf = hifld_gdf[['geometry', id_columns['HIFLD']] + similarity_columns['HIFLD']]
dh_filtered_gdf = dh_gdf[['geometry', id_columns['DH']] + similarity_columns['DH']]

# %%
joined_dh_hcris, db_dh_hcris = spatial_join_facilities(left=dh_filtered_gdf,
                        right=hcris_filtered_gdf,
                        lid_property = id_columns['DH'],
                        rid_property = id_columns['HCRIS'],
                        lsimilarity_properties = similarity_columns['DH'],
                        rsimilarity_properties = similarity_columns['HCRIS'],
                        similarity_weights=[0.6, 0.4],                                                       
                        distance=1000,
                        merge_unmatched=False)

# %%
joined_dh_hifld, db_dh_hifld = spatial_join_facilities(left=dh_filtered_gdf,
                        right=hifld_filtered_gdf,
                        lid_property = id_columns['DH'],
                        rid_property = id_columns['HIFLD'],
                        lsimilarity_properties = similarity_columns['DH'],
                        rsimilarity_properties = similarity_columns['HIFLD'],
                        similarity_weights=[0.6, 0.4],                                                       
                        distance=150,
                        merge_unmatched=False)

# %%
joined_dh_hcris[~joined_dh_hcris['Provider Number'].isnull()]
# Out:
#       OBJECTID Provider Number
# 5420      6421          673067
# 5281      6282          673066
# 5070      6071          673066
# 5227      6228          673065
# 3580      3581          673065
# ...        ...             ...
# 2036        37          010007
# 2067        68          010006
# 2076        77          010005
# 5920      5341          010001
# 6073      5494          010001
#
# [7057 rows x 2 columns]

# %%
joined_dh_hifld[joined_dh_hifld['ID'].isnull()]
# Out:
#    OBJECTID  ID
# 0      4001 NaN

# %%
dh_gdf[dh_gdf['OBJECTID'] == 6579]
# Out:
#       OBJECTID                                         HOSPITAL_N  \
# 5578      6579  Oceans Behavioral Hospital Greater New Orleans...
#
#                 HOSPITAL_T       HQ_ADDRESS HQ_ADDRE_1  HQ_CITY HQ_STATE  \
# 5578  Psychiatric Hospital  4500 Wichers Dr       None  Marrero       LA
#
#      HQ_ZIP_COD COUNTY_NAM STATE_NAME STATE_FIPS CNTY_FIPS   FIPS  NUM_LICENS  \
# 5578      70072  Jefferson  Louisiana         22       051  22051         NaN
#
#       NUM_STAFFE  NUM_ICU_BE  BED_UTILIZ  Potential_  \
# 5578         NaN         NaN         NaN           0
#
#                         geometry
# 5578  POINT (-90.09447 29.88922)

# %%
dh_gdf[dh_gdf['OBJECTID'] == 4001]
# Out:
#    OBJECTID                 HOSPITAL_N                      HOSPITAL_T  \
# 0      4001  Trios Southridge Hospital  Short Term Acute Care Hospital
#
#        HQ_ADDRESS HQ_ADDRE_1    HQ_CITY HQ_STATE HQ_ZIP_COD COUNTY_NAM  \
# 0  3810 Plaza Way       None  Kennewick       WA      99338     Benton
#
#    STATE_NAME STATE_FIPS CNTY_FIPS   FIPS  NUM_LICENS  NUM_STAFFE  NUM_ICU_BE  \
# 0  Washington         53       005  53005       111.0       111.0        14.0
#
#    BED_UTILIZ  Potential_                     geometry
# 0    0.455856           0  POINT (-119.19250 46.17759)

# %%
hcris_gdf[hcris_gdf['State'] == 'WA']
# Out:
#      Provider Number        FYB        FYE        STATUS  CTRL_TYPE  \
# 6173          500001  01-JUL-18  30-JUN-19  As Submitted          2
# 6174          500002  01-JAN-18  31-DEC-18  As Submitted          1
# 6175          500003  01-JAN-18  31-DEC-18  As Submitted         11
# 6176          500005  01-JAN-18  31-DEC-18       Amended          2
# 6177          500007  01-JAN-18  31-DEC-18       Amended          2
# ...              ...        ...        ...           ...        ...
# 6274          504004  01-JUL-18  30-JUN-19  As Submitted         10
# 6275          504008  01-SEP-18  30-JUN-19  As Submitted          1
# 6276          504009  01-JAN-18  31-DEC-18  As Submitted          2
# 6277          504011  01-JAN-18  31-DEC-18  As Submitted          4
# 6278          504012  01-JAN-18  31-DEC-18  As Submitted          5
#
#                             HOSP10_Name                Street_Addr PO_Box  \
# 6173     UW MEDICINE/NORTHWEST HOSPITAL    1550 NORTH 115TH STREET    NaN
# 6174        PROV ST MARY MEDICAL CENTER           401 W POPLAR ST.   1477
# 6175  PHD#1  DBA SKAGIT VALLEY HOSPITAL      1415 E KINCAID STREET    NaN
# 6176      VIRGINIA MASON MEDICAL CENTER          925 SENECA STREET   1930
# 6177                    ISLAND HOSPITAL           1211 24TH STREET    NaN
# ...                                 ...                        ...    ...
# 6274             EASTERN STATE HOSPITAL               MAPLE STREET    800
# 6275          LOURDES COUNSELING CENTER      1175 CARONDELET DRIVE    NaN
# 6276                              NAVOS      2600 SW HOLDEN STREET    NaN
# 6277          CASCADE BEHAVIORAL HEALTH  12844 MILITARY ROAD SOUTH    NaN
# 6278   SMOKEY POINT BEHAVIORAL HOSPITAL       3955 156TH STREET NE    NaN
#
#               City State  ... Surgical ICU Inpatient Days Total Staffed Beds  \
# 6173       SEATTLE    WA  ...                         0.0              179.0
# 6174   WALLA WALLA    WA  ...                         0.0              120.0
# 6175  MOUNT VERNON    WA  ...                         0.0              137.0
# 6176       SEATTLE    WA  ...                         0.0              211.0
# 6177     ANACORTES    WA  ...                         0.0               43.0
# ...            ...   ...  ...                         ...                ...
# 6274  MEDICAL LAKE    WA  ...                         0.0              317.0
# 6275      RICHLAND    WA  ...                         0.0               22.0
# 6276       SEATTLE    WA  ...                         0.0               43.0
# 6277       TUKWILA    WA  ...                         0.0              137.0
# 6278    MARYSVILLE    WA  ...                         0.0              115.0
#
#       Total Bed Days Available  Total Inpatient Days  ICU Total Staffed Beds  \
# 6173                   64219.0               41077.0                    32.0
# 6174                   41792.0               22150.0                    28.0
# 6175                   50005.0               36947.0                    12.0
# 6176                   77031.0               66969.0                    28.0
# 6177                   15695.0                8162.0                     6.0
# ...                        ...                   ...                     ...
# 6274                  115705.0               94676.0                     0.0
# 6275                    6666.0                5344.0                     0.0
# 6276                   15695.0               15525.0                     0.0
# 6277                   50005.0               41050.0                     0.0
# 6278                   41975.0               25415.0                     0.0
#
#       ICU Total Bed Days Available  ICU Total Inpatient Days  \
# 6173                       11680.0                    7962.0
# 6174                       10220.0                    4056.0
# 6175                        4380.0                    2222.0
# 6176                       10220.0                    6819.0
# 6177                        2190.0                     701.0
# ...                            ...                       ...
# 6274                           0.0                       0.0
# 6275                           0.0                       0.0
# 6276                           0.0                       0.0
# 6277                           0.0                       0.0
# 6278                           0.0                       0.0
#
#       ICU Occupancy Rate  Total Bed Occupancy Rate  \
# 6173            0.681678                  0.639639
# 6174            0.396869                  0.530006
# 6175            0.507306                  0.738866
# 6176            0.667221                  0.869377
# 6177            0.320091                  0.520038
# ...                  ...                       ...
# 6274                 NaN                  0.818253
# 6275                 NaN                  0.801680
# 6276                 NaN                  0.989169
# 6277                 NaN                  0.820918
# 6278                 NaN                  0.605479
#
#                          geometry
# 6173  POINT (-122.33704 47.71417)
# 6174  POINT (-118.34319 46.06209)
# 6175  POINT (-122.32452 48.41923)
# 6176  POINT (-122.32763 47.61001)
# 6177  POINT (-122.61498 48.50200)
# ...                           ...
# 6274  POINT (-117.69697 47.57201)
# 6275  POINT (-119.28139 46.28298)
# 6276  POINT (-122.36621 47.53419)
# 6277  POINT (-122.29615 47.48730)
# 6278  POINT (-122.17968 48.13881)
#
# [95 rows x 36 columns]

# %%
hcris_gdf
# Out:
#      Provider Number        FYB        FYE        STATUS  CTRL_TYPE  \
# 0             010001  01-OCT-17  30-SEP-18  As Submitted          9
# 1             010005  01-OCT-17  30-SEP-18  As Submitted          9
# 2             010006  01-JUL-18  30-JUN-19  As Submitted          4
# 3             010007  01-OCT-17  30-SEP-18  As Submitted          9
# 4             010008  01-JAN-18  31-DEC-18  As Submitted          4
# ...              ...        ...        ...           ...        ...
# 6655          673062  01-JAN-18  31-DEC-18  As Submitted          4
# 6657          673064  01-APR-18  31-MAR-19  As Submitted          6
# 6658          673065  01-OCT-17  30-SEP-18  As Submitted          5
# 6659          673066  10-NOV-17  30-SEP-18  As Submitted          4
# 6660          673067  25-MAY-18  31-MAY-19  As Submitted          5
#
#                                HOSP10_Name                  Street_Addr  \
# 0          SOUTHEAST HEALTH MEDICAL CENTER       1108 ROSS CLARK CIRCLE
# 1          MARSHALL MEDICAL CENTER - SOUTH        2505 U.S. HIGHWAY 431
# 2             NORTH ALABAMA MEDICAL CENTER          1701 VETERANS DRIVE
# 3                 MIZELL MEMORIAL HOSPITAL              702 MAIN STREET
# 4              CRENSHAW COMMUNITY HOSPITAL  CRENSHAW COMMUNITY HOSPITAL
# ...                                    ...                          ...
# 6655    WEATHERFORD REABILITATION HOSPITAL                703 EUREKA ST
# 6657         ICARE REHABILITATION HOSPITAL      3100 PETERS COLONY ROAD
# 6658  CHI ST. JOSEPH HEALTH REHABILITATION            1600 JOSEPH DRIVE
# 6659  ENCOMPASS HEALTH REHABILITATION HOSP   2121 BUSINESS CENTER DRIVE
# 6660     PAM REHAB HOSPITAL CORPUS CHRISTI          345 S. WATER STREET
#
#                    PO_Box           City State  ...  \
# 0                    6987         DOTHAN    AL  ...
# 1                     NaN           BOAZ    AL  ...
# 2                     818       FLORENCE    AL  ...
# 3                     429            OPP    AL  ...
# 4     101 HOSPITAL CIRCLE        LUVERNE    AL  ...
# ...                   ...            ...   ...  ...
# 6655                  NaN    WEATHERFORD    TX  ...
# 6657                  NaN   FLOWER MOUND    TX  ...
# 6658                  NaN          BRYAN    TX  ...
# 6659                  NaN       PEARLAND    TX  ...
# 6660                  NaN  CORPUS CHRIST    TX  ...
#
#      Surgical ICU Inpatient Days Total Staffed Beds  Total Bed Days Available  \
# 0                            0.0              327.0                  119355.0
# 1                            0.0              204.0                   74460.0
# 2                            0.0              233.0                  104170.0
# 3                            0.0               45.0                   16425.0
# 4                            0.0               29.0                   10585.0
# ...                          ...                ...                       ...
# 6655                         0.0               26.0                    9490.0
# 6657                         0.0               41.0                   14965.0
# 6658                         0.0               49.0                   17885.0
# 6659                         0.0               40.0                   13000.0
# 6660                         0.0               40.0                   14880.0
#
#       Total Inpatient Days  ICU Total Staffed Beds  \
# 0                  95560.0                    40.0
# 1                  38089.0                    20.0
# 2                  61969.0                    52.0
# 3                   4571.0                     5.0
# 4                   1334.0                     0.0
# ...                    ...                     ...
# 6655                5582.0                     0.0
# 6657                3532.0                     0.0
# 6658               15895.0                     0.0
# 6659                8997.0                     0.0
# 6660                8565.0                     0.0
#
#       ICU Total Bed Days Available  ICU Total Inpatient Days  \
# 0                          14600.0                   11992.0
# 1                           7300.0                    5283.0
# 2                          18368.0                   13247.0
# 3                           1825.0                    1126.0
# 4                              0.0                       0.0
# ...                            ...                       ...
# 6655                           0.0                       0.0
# 6657                           0.0                       0.0
# 6658                           0.0                       0.0
# 6659                           0.0                       0.0
# 6660                           0.0                       0.0
#
#       ICU Occupancy Rate  Total Bed Occupancy Rate                    geometry
# 0               0.821370                  0.800637  POINT (-85.36253 31.21591)
# 1               0.723699                  0.511536  POINT (-86.16006 34.22140)
# 2               0.721200                  0.594883  POINT (-87.65095 34.80439)
# 3               0.616986                  0.278295  POINT (-86.25417 31.29198)
# 4                    NaN                  0.126027  POINT (-86.26472 31.69361)
# ...                  ...                       ...                         ...
# 6655                 NaN                  0.588198  POINT (-97.78775 32.75068)
# 6657                 NaN                  0.236017  POINT (-97.07724 33.03534)
# 6658                 NaN                  0.888734  POINT (-96.35061 30.66043)
# 6659                 NaN                  0.692077  POINT (-95.39012 29.57310)
# 6660                 NaN                  0.575605  POINT (-97.39522 27.78942)
#
# [5559 rows x 36 columns]

# %%
dh_gdf
# Out:
#       OBJECTID                                         HOSPITAL_N  \
# 0         4001                          Trios Southridge Hospital
# 1         4002  Kadlec Regional Medical Center (AKA Kadlec Hea...
# 2         4003                        Central Washington Hospital
# 3         4004                          Wenatchee Valley Hospital
# 4         4005                     Lake Chelan Community Hospital
# ...        ...                                                ...
# 6575      5996  Cirby Hills Behavioral Hospital (FKA Telecare ...
# 6576      5997                                        The Meadows
# 6577      5998          The Menninger Clinic Psychiatric Hospital
# 6578      5999                           The Orthopedic Institute
# 6579      6000           Treasure Coast Forensic Treatment Center
#
#                           HOSPITAL_T           HQ_ADDRESS HQ_ADDRE_1  \
# 0     Short Term Acute Care Hospital       3810 Plaza Way       None
# 1     Short Term Acute Care Hospital       888 Swift Blvd       None
# 2     Short Term Acute Care Hospital     1201 S Miller St       None
# 3     Short Term Acute Care Hospital     820 N Chelan Ave       None
# 4           Critical Access Hospital   503 E Highland Ave       None
# ...                              ...                  ...        ...
# 6575            Psychiatric Hospital   101 Cirby Hills Dr       None
# 6576            Psychiatric Hospital     1655 N Tegner St       None
# 6577            Psychiatric Hospital        12301 Main St       None
# 6578  Short Term Acute Care Hospital      27 Parkway Blvd       None
# 6579            Psychiatric Hospital  96 Sw Allapattah Rd       None
#
#           HQ_CITY HQ_STATE HQ_ZIP_COD COUNTY_NAM   STATE_NAME STATE_FIPS  \
# 0       Kennewick       WA      99338     Benton   Washington         53
# 1        Richland       WA      99352     Benton   Washington         53
# 2       Wenatchee       WA      98801     Chelan   Washington         53
# 3       Wenatchee       WA      98801     Chelan   Washington         53
# 4          Chelan       WA      98816     Chelan   Washington         53
# ...           ...      ...        ...        ...          ...        ...
# 6575    Roseville       CA      95678     Placer   California         06
# 6576   Wickenburg       AZ      85390   Maricopa      Arizona         04
# 6577      Houston       TX      77035     Harris        Texas         48
# 6578  Hattiesburg       MS      39401    Forrest  Mississippi         28
# 6579   Indiantown       FL      34956     Martin      Florida         12
#
#      CNTY_FIPS   FIPS  NUM_LICENS  NUM_STAFFE  NUM_ICU_BE  BED_UTILIZ  \
# 0          005  53005       111.0       111.0        14.0    0.455856
# 1          005  53005       258.0       258.0        30.0    0.738080
# 2          007  53007       176.0       176.0        20.0    0.693867
# 3          007  53007        11.0        11.0         NaN    0.233873
# 4          007  53007        25.0        25.0         NaN    0.677041
# ...        ...    ...         ...         ...         ...         ...
# 6575       061  06061        16.0        16.0         NaN         NaN
# 6576       013  04013         NaN         NaN         NaN         NaN
# 6577       201  48201       120.0       120.0         NaN         NaN
# 6578       035  28035        30.0        30.0         NaN         NaN
# 6579       085  12085         NaN         NaN         NaN         NaN
#
#       Potential_                     geometry
# 0              0  POINT (-119.19250 46.17759)
# 1              0  POINT (-119.28248 46.28124)
# 2              0  POINT (-120.32429 47.40771)
# 3              0  POINT (-120.32263 47.43363)
# 4              0  POINT (-120.01040 47.84510)
# ...          ...                          ...
# 6575           0  POINT (-121.28634 38.73032)
# 6576           0  POINT (-112.73960 33.98510)
# 6577           0   POINT (-95.45740 29.64700)
# 6578           0   POINT (-89.28588 31.27088)
# 6579           0   POINT (-80.48280 27.20450)
#
# [6563 rows x 19 columns]

# %%
joined_dh_hifld[~joined_dh_hifld['ID'].isnull()]
# Out:
#       OBJECTID           ID
# 5338      6339  180443082.0
# 5370      6371  180374133.0
# 5363      6364  180274012.0
# 5965      5386  179848912.0
# 1882      1883  179848912.0
# ...        ...          ...
# 5703      5124         81.0
# 1503      1504         71.0
# 4360      2361         63.0
# 4061      2062         57.0
# 3774      3775         38.0
#
# [5466 rows x 2 columns]

# %%
dh_hifld_df = joined_dh_hifld.merge(dh_gdf, on='OBJECTID')
dh_hifld_df = dh_hifld_df.merge(hifld_gdf, on='ID')

# %%
dh_hifld_df['DIFF'] = dh_hifld_df['NUM_LICENS'] - dh_hifld_df['BEDS']

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %%
dh_hifld_df[dh_hifld_df['DIFF'] > 50]
# Out:
#       OBJECTID_x           ID  \
# 4           1883  179848912.0
# 9           2115  179339501.0
# 31          6412  175058103.0
# 49           505  168494117.0
# 54          3632   74575246.0
# ...          ...          ...
# 5414        1812     202176.0
# 5418        3173     197216.0
# 5438        2006     155454.0
# 5447        3278     118017.0
# 5461        3459         83.0
#
#                                              HOSPITAL_N  \
# 4                                      Sparrow Hospital
# 9                         Memorial Hospital at Gulfport
# 31                   Sanford Childrens Hospital - Fargo
# 49                              St Marys Medical Center
# 54            Baylor University Medical Center - Dallas
# ...                                                 ...
# 5414                          MelroseWakefield Hospital
# 5418                          Adventist Health Portland
# 5438  M Health Fairview University of Minnesota Medi...
# 5447                Lehigh Valley Hospital - Muhlenberg
# 5461  Tennova Healthcare - Cleveland (FKA Skyridge M...
#
#                           HOSPITAL_T              HQ_ADDRESS   HQ_ADDRE_1  \
# 4     Short Term Acute Care Hospital     1215 E Michigan Ave         None
# 9     Short Term Acute Care Hospital            4500 13th St  PO BOX 1810
# 31                Childrens Hospital         5225 23rd Ave S         None
# 49    Short Term Acute Care Hospital          450 Stanyan St         None
# 54    Short Term Acute Care Hospital         3500 Gaston Ave         None
# ...                              ...                     ...          ...
# 5414  Short Term Acute Care Hospital          585 Lebanon St         None
# 5418  Short Term Acute Care Hospital      10123 Se Market St         None
# 5438  Short Term Acute Care Hospital      2450 Riverside Ave         None
# 5447  Short Term Acute Care Hospital  2545 Schoenersville Rd         None
# 5461  Short Term Acute Care Hospital   2305 Chambliss Ave Nw         None
#
#             HQ_CITY HQ_STATE HQ_ZIP_COD     COUNTY_NAM     STATE_NAME  \
# 4           Lansing       MI      48912         Ingham       Michigan
# 9          Gulfport       MS      39501       Harrison    Mississippi
# 31            Fargo       ND      58104           Cass   North Dakota
# 49    San Francisco       CA      94117  San Francisco     California
# 54           Dallas       TX      75246         Dallas          Texas
# ...             ...      ...        ...            ...            ...
# 5414        Melrose       MA       2176      Middlesex  Massachusetts
# 5418       Portland       OR      97216      Multnomah         Oregon
# 5438    Minneapolis       MN      55454       Hennepin      Minnesota
# 5447      Bethlehem       PA      18017         Lehigh   Pennsylvania
# 5461      Cleveland       TN      37311        Bradley      Tennessee
#
#      STATE_FIPS CNTY_FIPS   FIPS  NUM_LICENS  NUM_STAFFE  NUM_ICU_BE  \
# 4            26       065  26065       573.0       533.0        99.0
# 9            28       047  28047       445.0       281.0        26.0
# 31           38       017  38017       284.0       284.0         NaN
# 49           06       075  06075       272.0       113.0        19.0
# 54           48       113  48113       914.0       824.0       128.0
# ...         ...       ...    ...         ...         ...         ...
# 5414         25       017  25017       234.0       234.0        12.0
# 5418         41       051  41051       302.0       168.0        12.0
# 5438         27       053  27053      1700.0       778.0        21.0
# 5447         42       077  42077       256.0       194.0        30.0
# 5461         47       011  47011       251.0       183.0        27.0
#
#       BED_UTILIZ  Potential_                   geometry_x           X  \
# 4       0.705796          40   POINT (-84.53519 42.73415)  -84.535963
# 9       0.680690         164   POINT (-89.11530 30.36670)  -89.116036
# 31           NaN           0   POINT (-96.87650 46.84545)  -96.875779
# 49      0.474821         159  POINT (-122.45389 37.77407) -122.454030
# 54      0.735833          90   POINT (-96.78059 32.78994)  -96.780290
# ...          ...         ...                          ...         ...
# 5414    0.579640           0   POINT (-71.06101 42.46041)  -71.060900
# 5418    0.480072         134  POINT (-122.55839 45.51309) -122.558434
# 5438    0.757977         922   POINT (-93.23711 44.96781)  -93.238075
# 5447    0.675241          62   POINT (-75.40868 40.64490)  -75.408063
# 5461    0.571704          68   POINT (-84.86933 35.17735)  -84.869906
#
#               Y  OBJECTID_y  \
# 4     42.734195        3938
# 9     30.367418        4155
# 31    46.845219        3867
# 49    37.774039        3891
# 54    32.790265        4170
# ...         ...         ...
# 5414  42.460500        2433
# 5418  45.512710        7061
# 5438  44.967734        6801
# 5447  40.644616        6667
# 5461  35.177198        7298
#
#                                                    NAME  \
# 4                            SPARROW SPECIALTY HOSPITAL
# 9       HEALTHSOUTH REHABILITATION HOSPITAL OF GULFPORT
# 31                         SANFORD MEDICAL CENTER FARGO
# 49                     KENTFIELD HOSPITAL SAN FRANCISCO
# 54        SELECT SPECIALTY HOSPITAL - DALLAS (DOWNTOWN)
# ...                                                 ...
# 5414  HALLMARK HEALTH SYSTEM - MELROSE-WAKEFIELD HOS...
# 5418                           ADVENTIST MEDICAL CENTER
# 5438                           UNIVERSITY OF MN MED CTR
# 5447                   GOOD SHEPHERD SPECIALTY HOSPITAL
# 5461                     TENNOVA HEALTHCARE - CLEVELAND
#
#                                     ADDRESS           CITY STATE    ZIP  \
# 4                1215 E MICHIGAN AVENUE, 8W        LANSING    MI  48912
# 9               4500 13TH STREET, 3RD FLOOR       GULFPORT    MS  39501
# 31                          5225 23RD AVE S          FARGO    ND  58103
# 49                          450 STANYAN ST.  SAN FRANCISCO    CA  94117
# 54    3500 GASTON AVENUE, 3RD AND 4TH FLOOR         DALLAS    TX  75246
# ...                                     ...            ...   ...    ...
# 5414                     585 LEBANON STREET        MELROSE    MA   2176
# 5418                 10123 SE MARKET STREET       PORTLAND    OR  97216
# 5438                  2450 RIVERSIDE AVENUE    MINNEAPOLIS    MN  55454
# 5447               2545 SCHOENERSVILLE ROAD      BETHLEHEM    PA  18017
# 5461                  2305 CHAMBLISS AVE NW      CLEVELAND    TN  37311
#
#                ZIP4       TELEPHONE                TYPE STATUS  POPULATION  \
# 4     NOT AVAILABLE   NOT AVAILABLE      LONG TERM CARE   OPEN          30
# 9              2515  (228) 822-6965      REHABILITATION   OPEN          33
# 31    NOT AVAILABLE  (701) 234-6919  GENERAL ACUTE CARE   OPEN         228
# 49    NOT AVAILABLE   NOT AVAILABLE      LONG TERM CARE   OPEN          60
# 54    NOT AVAILABLE  (972) 227-0093      LONG TERM CARE   OPEN          46
# ...             ...             ...                 ...    ...         ...
# 5414  NOT AVAILABLE  (781) 979-3000  GENERAL ACUTE CARE   OPEN         174
# 5418  NOT AVAILABLE   NOT AVAILABLE  GENERAL ACUTE CARE   OPEN         217
# 5438  NOT AVAILABLE  (612) 273-3000  GENERAL ACUTE CARE   OPEN         825
# 5447  NOT AVAILABLE  (484) 884-5051      LONG TERM CARE   OPEN          32
# 5461  NOT AVAILABLE  (423) 559-6000  GENERAL ACUTE CARE   OPEN         140
#
#              COUNTY COUNTYFIPS COUNTRY   LATITUDE   LONGITUDE  NAICS_CODE  \
# 4            INGHAM      26065     USA  42.734195  -84.535963      622310
# 9          HARRISON      28047     USA  30.367418  -89.116036      622310
# 31             CASS      38017     USA  46.845219  -96.875779      622110
# 49    SAN FRANCISCO      06075     USA  37.774039 -122.454030      622310
# 54           DALLAS      48113     USA  32.790265  -96.780290      622310
# ...             ...        ...     ...        ...         ...         ...
# 5414      MIDDLESEX      25017     USA  42.460500  -71.060900      622110
# 5418      MULTNOMAH      41051     USA  45.512710 -122.558434      622110
# 5438       HENNEPIN      27053     USA  44.967734  -93.238075      622110
# 5447         LEHIGH      42077     USA  40.644616  -75.408063      622310
# 5461        BRADLEY      47011     USA  35.177198  -84.869906      622110
#
#                                              NAICS_DESC  \
# 4     SPECIALTY (EXCEPT PSYCHIATRIC AND SUBSTANCE AB...
# 9                     PHYSICAL REHABILITATION HOSPITALS
# 31               GENERAL MEDICAL AND SURGICAL HOSPITALS
# 49    EXTENDED CARE HOSPITALS (EXCEPT MENTAL, SUBSTA...
# 54    SPECIALTY (EXCEPT PSYCHIATRIC AND SUBSTANCE AB...
# ...                                                 ...
# 5414             GENERAL MEDICAL AND SURGICAL HOSPITALS
# 5418             GENERAL MEDICAL AND SURGICAL HOSPITALS
# 5438             GENERAL MEDICAL AND SURGICAL HOSPITALS
# 5447  SPECIALTY (EXCEPT PSYCHIATRIC AND SUBSTANCE AB...
# 5461             GENERAL MEDICAL AND SURGICAL HOSPITALS
#
#                                                  SOURCE           SOURCEDATE  \
# 4        https://w2.lara.state.mi.us/VAL/License/Search  2018-08-09T00:00:00
# 9     https://msdh.ms.gov/msdhsite/_static/resources...  2018-08-09T00:00:00
# 31    http://www.ndhealth.gov/HF/North_Dakota_Hospit...  2018-08-09T00:00:00
# 49    http://www.oshpd.ca.gov/HID/Facility-Listing.html  2018-08-08T00:00:00
# 54    http://www.dshs.texas.gov/facilities/find-a-li...  2018-08-11T00:00:00
# ...                                                 ...                  ...
# 5414  http://www.mass.gov/eohhs/gov/departments/dph/...  2018-08-16T00:00:00
# 5418  https://public.health.oregon.gov/ProviderPartn...  2018-08-10T00:00:00
# 5438  http://www.health.state.mn.us/divs/fpc/directo...  2018-08-09T00:00:00
# 5447  http://sais.health.pa.gov/commonpoc/content/pu...  2018-08-09T00:00:00
# 5461        https://apps.health.tn.gov/FacilityListings  2018-08-10T00:00:00
#
#          VAL_METHOD             VAL_DATE  \
# 4     IMAGERY/OTHER  2019-05-09T00:00:00
# 9     IMAGERY/OTHER  2019-05-09T00:00:00
# 31          IMAGERY  2019-05-09T00:00:00
# 49    IMAGERY/OTHER  2019-05-10T00:00:00
# 54    IMAGERY/OTHER  2016-12-02T00:00:00
# ...             ...                  ...
# 5414  IMAGERY/OTHER  2014-02-10T00:00:00
# 5418  IMAGERY/OTHER  2014-03-12T00:00:00
# 5438        IMAGERY  2014-03-12T00:00:00
# 5447        IMAGERY  2014-02-10T00:00:00
# 5461  IMAGERY/OTHER  2015-05-22T00:00:00
#
#                                                 WEBSITE         STATE_ID  \
# 4                            http://www.sparrow.org/SSH       1060000149
# 9                       http://healthsouthgulfport.com/  LICENSE #42-350
# 31                        http://www.sanfordhealth.org/             5070
# 49                http://www.kentfieldsanfrancisco.com/    NOT AVAILABLE
# 54    http://dallasdowntown.selectspecialtyhospitals...    NOT AVAILABLE
# ...                                                 ...              ...
# 5414  http://www.hallmarkhealth.org/melrose-wakefiel...             2058
# 5418                          www.adventisthealthnw.com          14-1127
# 5438                            https://www.mhealth.org              200
# 5447  http://www.goodshepherdrehab.org/long-term-acu...           003100
# 5461  http://www.tennovaeast.com/locations/tennova-h...    NOT AVAILABLE
#
#                         ALT_NAME  ST_FIPS        OWNER  TTL_STAFF  BEDS  \
# 4                  NOT AVAILABLE       26   NON-PROFIT       -999    30
# 9                  NOT AVAILABLE       28  PROPRIETARY       -999    33
# 31                 NOT AVAILABLE       38   NON-PROFIT       -999   228
# 49                 NOT AVAILABLE        6  PROPRIETARY       -999    60
# 54                 NOT AVAILABLE       48  PROPRIETARY       -999    46
# ...                          ...      ...          ...        ...   ...
# 5414  MELROSE-WAKEFIELD HOSPITAL       25   NON-PROFIT       -999   174
# 5418               NOT AVAILABLE       41   NON-PROFIT       -999   217
# 5438               NOT AVAILABLE       27   NON-PROFIT       -999   825
# 5447               NOT AVAILABLE       42   NON-PROFIT       -999    32
# 5461     SKYRIDGE MEDICAL CENTER       47  PROPRIETARY       -999   140
#
#                   TRAUMA HELIPAD                   geometry_y   DIFF
# 4          NOT AVAILABLE       Y   POINT (-84.53596 42.73419)  543.0
# 9          NOT AVAILABLE       Y   POINT (-89.11604 30.36742)  412.0
# 31    LEVEL II PEDIATRIC       Y   POINT (-96.87578 46.84522)   56.0
# 49         NOT AVAILABLE       N  POINT (-122.45403 37.77404)  212.0
# 54         NOT AVAILABLE       Y   POINT (-96.78029 32.79027)  868.0
# ...                  ...     ...                          ...    ...
# 5414       NOT AVAILABLE       N   POINT (-71.06090 42.46050)   60.0
# 5418       NOT AVAILABLE       Y  POINT (-122.55843 45.51271)   85.0
# 5438            LEVEL II       Y   POINT (-93.23808 44.96773)  875.0
# 5447       NOT AVAILABLE       N   POINT (-75.40806 40.64462)  224.0
# 5461       NOT AVAILABLE       Y   POINT (-84.86991 35.17720)  111.0
#
# [383 rows x 55 columns]

# %%
dh_hifld_df['DIFF'] = dh_hifld_df['NUM_LICENS'] - dh_hifld_df['BEDS']

# %%
# Check DF and HCRIS

dh_hcris_df = joined_dh_hcris.merge(dh_gdf, on='OBJECTID')
dh_hcris_df = dh_hcris_df.merge(hcris_gdf, on='Provider Number', how='left')

# %%
dh_hcris_df['DIFF'] = dh_hcris_df['NUM_ICU_BE'] - dh_hcris_df['ICU Total Staffed Beds']

# %%
dh_hcris_df[dh_hcris_df['DIFF'] > 50]
# Out:
#       OBJECTID Provider Number  \
# 18        3690          673061
# 19        3690          670008
# 225       3632          670108
# 226       3632          453036
# 227       3632          452105
# ...        ...             ...
# 6333       325          050063
# 6363       491          052044
# 6446       424          050696
# 6447       424          050660
# 6818       144          034004
#
#                                              HOSPITAL_N  \
# 18    Clear Lake Regional Medical Center (AKA HCA Ho...
# 19    Clear Lake Regional Medical Center (AKA HCA Ho...
# 225           Baylor University Medical Center - Dallas
# 226           Baylor University Medical Center - Dallas
# 227           Baylor University Medical Center - Dallas
# ...                                                 ...
# 6333     Kaiser Permanente - Los Angeles Medical Center
# 6363                   Scripps Mercy Hospital San Diego
# 6446                           LAC & USC Medical Center
# 6447                           LAC & USC Medical Center
# 6818       HonorHealth Scottsdale Osborn Medical Center
#
#                           HOSPITAL_T               HQ_ADDRESS HQ_ADDRE_1  \
# 18    Short Term Acute Care Hospital  500 Medical Center Blvd       None
# 19    Short Term Acute Care Hospital  500 Medical Center Blvd       None
# 225   Short Term Acute Care Hospital          3500 Gaston Ave       None
# 226   Short Term Acute Care Hospital          3500 Gaston Ave       None
# 227   Short Term Acute Care Hospital          3500 Gaston Ave       None
# ...                              ...                      ...        ...
# 6333  Short Term Acute Care Hospital       4867 W Sunset Blvd       None
# 6363  Short Term Acute Care Hospital             4077 5th Ave       None
# 6446  Short Term Acute Care Hospital          2051 Marengo St       None
# 6447  Short Term Acute Care Hospital          2051 Marengo St       None
# 6818  Short Term Acute Care Hospital         7400 E Osborn Rd       None
#
#           HQ_CITY HQ_STATE HQ_ZIP_COD   COUNTY_NAM  STATE_NAME STATE_FIPS  \
# 18        Webster       TX      77598       Harris       Texas         48
# 19        Webster       TX      77598       Harris       Texas         48
# 225        Dallas       TX      75246       Dallas       Texas         48
# 226        Dallas       TX      75246       Dallas       Texas         48
# 227        Dallas       TX      75246       Dallas       Texas         48
# ...           ...      ...        ...          ...         ...        ...
# 6333  Los Angeles       CA      90027  Los Angeles  California         06
# 6363    San Diego       CA      92103    San Diego  California         06
# 6446  Los Angeles       CA      90033  Los Angeles  California         06
# 6447  Los Angeles       CA      90033  Los Angeles  California         06
# 6818   Scottsdale       AZ      85251     Maricopa     Arizona         04
#
#      CNTY_FIPS   FIPS  NUM_LICENS  NUM_STAFFE  NUM_ICU_BE  BED_UTILIZ  \
# 18         201  48201       532.0       532.0        86.0    0.721923
# 19         201  48201       532.0       532.0        86.0    0.721923
# 225        113  48113       914.0       824.0       128.0    0.735833
# 226        113  48113       914.0       824.0       128.0    0.735833
# 227        113  48113       914.0       824.0       128.0    0.735833
# ...        ...    ...         ...         ...         ...         ...
# 6333       037  06037       460.0       460.0        96.0    0.727826
# 6363       073  06073       482.0       487.0        56.0    0.710489
# 6446       037  06037       600.0       594.0       128.0    0.801218
# 6447       037  06037       600.0       594.0       128.0    0.801218
# 6818       013  04013       341.0       337.0        59.0    0.499648
#
#       Potential_                   geometry_x        FYB        FYE  \
# 18             0   POINT (-95.12780 29.54110)  01-JUN-18  31-MAY-19
# 19             0   POINT (-95.12780 29.54110)  01-JAN-18  31-DEC-18
# 225           90   POINT (-96.78059 32.78994)  01-JUN-18  31-MAY-19
# 226           90   POINT (-96.78059 32.78994)  01-JUL-18  30-JUN-19
# 227           90   POINT (-96.78059 32.78994)  01-JAN-18  31-DEC-18
# ...          ...                          ...        ...        ...
# 6333           0  POINT (-118.29459 34.09834)  01-JAN-18  31-DEC-18
# 6363          -5  POINT (-117.16039 32.75157)  01-APR-18  31-MAR-19
# 6446           6  POINT (-118.20798 34.05771)  01-OCT-17  30-SEP-18
# 6447           6  POINT (-118.20798 34.05771)  01-OCT-17  30-SEP-18
# 6818           4  POINT (-111.92300 33.48870)  01-JAN-18  31-DEC-18
#
#             STATUS  CTRL_TYPE                           HOSP10_Name  \
# 18    As Submitted        5.0               BAY AREA REHAB HOSPITAL
# 19    As Submitted        4.0   WEBSTER SURGICAL SPECIALTY HOSPITAL
# 225        Amended        1.0   BAYLOR SCOTT & WHITE - MARBLE FALLS
# 226   As Submitted        4.0   BAYLOR INSTITUTE FOR REHABILITATION
# 227   As Submitted        2.0  BAYLOR SCOTT & WHITE CONTINUING CARE
# ...            ...        ...                                   ...
# 6333  As Submitted        4.0   HOLLYWOOD PRESBYTERIAN MEDICAL CNTR
# 6363  As Submitted        4.0  SELECT SPECIALTY HOSPITAL - SAN DIEG
# 6446  As Submitted        2.0                  KECK HOSPITAL OF USC
# 6447  As Submitted        2.0            USC NORRIS CANCER HOSPITAL
# 6818  As Submitted        2.0     BANNER BEHAVIORAL HEALTH HOSPITAL
#
#                           Street_Addr PO_Box          City State    Zip_Code  \
# 18    110 E. MEDICAL CENTER BOULEVARD    NaN       WEBSTER    TX       77598
# 19                333 N. TEXAS AVENUE    NaN       WEBSTER    TX      77598-
# 225               810 WEST HIGHWAY 71    NaN  MARBLE FALLS    TX       78654
# 226       909 NORTH WASHINGTON AVENUE    NaN        DALLAS    TX  75246-1520
# 227                   546 KEGLEY ROAD    NaN        TEMPLE    TX       76502
# ...                               ...    ...           ...   ...         ...
# 6333        1300 NORTH VERMONT AVENUE    NaN   LOS ANGELES    CA       90027
# 6363            555 WASHINGTON STREET    NaN     SAN DIEGO    CA       92103
# 6446            1500 SAN PABLO STREET    NaN   LOS ANGELES    CA      90033-
# 6447                1441 EASTLAKE AVE    NaN   LOS ANGELES    CA      90033-
# 6818            7575 EAST EARLL DRIVE    NaN    SCOTTSDALE    AZ       85251
#
#            County  Hospital Adult and Peds Staffed Beds  \
# 18         HARRIS                                  45.0
# 19         HARRIS                                  21.0
# 225           NaN                                  38.0
# 226        DALLAS                                  92.0
# 227          BELL                                  25.0
# ...           ...                                   ...
# 6333  LOS ANGELES                                 266.0
# 6363       SHASTA                                 110.0
# 6446  LOS ANGELES                                 237.0
# 6447  LOS ANGELES                                  53.0
# 6818     MARICOPA                                 124.0
#
#       Hospital Adult and Peds Bed Days Available  \
# 18                                       16425.0
# 19                                        7665.0
# 225                                      13870.0
# 226                                      33580.0
# 227                                       9125.0
# ...                                          ...
# 6333                                     97090.0
# 6363                                     40150.0
# 6446                                     86505.0
# 6447                                     19345.0
# 6818                                     45260.0
#
#       Hospital Adult and Peds Inpatient Days  \
# 18                                   12479.0
# 19                                    1562.0
# 225                                   6003.0
# 226                                  27926.0
# 227                                   7137.0
# ...                                      ...
# 6333                                 40705.0
# 6363                                 21356.0
# 6446                                 54560.0
# 6447                                 12547.0
# 6818                                 38838.0
#
#       Intensive Care Unit Staffed Beds  \
# 18                                 0.0
# 19                                 0.0
# 225                                8.0
# 226                                0.0
# 227                                0.0
# ...                                ...
# 6333                              36.0
# 6363                               0.0
# 6446                              46.0
# 6447                               7.0
# 6818                               0.0
#
#       Intensive Care Unit Bed Days Available  \
# 18                                       0.0
# 19                                       0.0
# 225                                   2920.0
# 226                                      0.0
# 227                                      0.0
# ...                                      ...
# 6333                                 13140.0
# 6363                                     0.0
# 6446                                 16790.0
# 6447                                  2555.0
# 6818                                     0.0
#
#       Intensive Care Unit Inpatient Days  Coronary Care Unit Staffed Beds  \
# 18                                   0.0                              0.0
# 19                                   0.0                              0.0
# 225                               1290.0                              0.0
# 226                                  0.0                              0.0
# 227                                  0.0                              0.0
# ...                                  ...                              ...
# 6333                              6434.0                              0.0
# 6363                                 0.0                              0.0
# 6446                             15540.0                             18.0
# 6447                              1113.0                              0.0
# 6818                                 0.0                              0.0
#
#       Coronary Care Unit Bed Days Available  \
# 18                                      0.0
# 19                                      0.0
# 225                                     0.0
# 226                                     0.0
# 227                                     0.0
# ...                                     ...
# 6333                                    0.0
# 6363                                    0.0
# 6446                                 6570.0
# 6447                                    0.0
# 6818                                    0.0
#
#       Coronary Care Unit Inpatient Days  Burn ICU Staffed Beds  \
# 18                                  0.0                    0.0
# 19                                  0.0                    0.0
# 225                                 0.0                    0.0
# 226                                 0.0                    0.0
# 227                                 0.0                    0.0
# ...                                 ...                    ...
# 6333                                0.0                    0.0
# 6363                                0.0                    0.0
# 6446                             8613.0                    0.0
# 6447                                0.0                    0.0
# 6818                                0.0                    0.0
#
#       Burn ICU Bed Days Available  Burn ICU Inpatient Days  \
# 18                            0.0                      0.0
# 19                            0.0                      0.0
# 225                           0.0                      0.0
# 226                           0.0                      0.0
# 227                           0.0                      0.0
# ...                           ...                      ...
# 6333                          0.0                      0.0
# 6363                          0.0                      0.0
# 6446                          0.0                      0.0
# 6447                          0.0                      0.0
# 6818                          0.0                      0.0
#
#       Surgical ICU Staffed Beds  Surgical ICU Bed Days Available  \
# 18                          0.0                              0.0
# 19                          0.0                              0.0
# 225                         0.0                              0.0
# 226                         0.0                              0.0
# 227                         0.0                              0.0
# ...                         ...                              ...
# 6333                        0.0                              0.0
# 6363                        0.0                              0.0
# 6446                        0.0                              0.0
# 6447                        0.0                              0.0
# 6818                        0.0                              0.0
#
#       Surgical ICU Inpatient Days  Total Staffed Beds  \
# 18                            0.0                45.0
# 19                            0.0                21.0
# 225                           0.0                46.0
# 226                           0.0                92.0
# 227                           0.0                25.0
# ...                           ...                 ...
# 6333                          0.0               317.0
# 6363                          0.0               110.0
# 6446                          0.0               301.0
# 6447                          0.0                60.0
# 6818                          0.0               124.0
#
#       Total Bed Days Available  Total Inpatient Days  ICU Total Staffed Beds  \
# 18                     16425.0               12479.0                     0.0
# 19                      7665.0                1562.0                     0.0
# 225                    16790.0                7888.0                     8.0
# 226                    33580.0               27926.0                     0.0
# 227                     9125.0                7137.0                     0.0
# ...                        ...                   ...                     ...
# 6333                  115705.0               57819.0                    36.0
# 6363                   40150.0               21356.0                     0.0
# 6446                  109865.0               78713.0                    64.0
# 6447                   21900.0               13660.0                     7.0
# 6818                   45260.0               38838.0                     0.0
#
#       ICU Total Bed Days Available  ICU Total Inpatient Days  \
# 18                             0.0                       0.0
# 19                             0.0                       0.0
# 225                         2920.0                    1290.0
# 226                            0.0                       0.0
# 227                            0.0                       0.0
# ...                            ...                       ...
# 6333                       13140.0                    6434.0
# 6363                           0.0                       0.0
# 6446                       23360.0                   24153.0
# 6447                        2555.0                    1113.0
# 6818                           0.0                       0.0
#
#       ICU Occupancy Rate  Total Bed Occupancy Rate  \
# 18                   NaN                  0.759756
# 19                   NaN                  0.203783
# 225             0.441781                  0.469803
# 226                  NaN                  0.831626
# 227                  NaN                  0.782137
# ...                  ...                       ...
# 6333            0.489650                  0.499710
# 6363                 NaN                  0.531905
# 6446            1.033947                  0.716452
# 6447            0.435616                  0.623744
# 6818                 NaN                  0.858109
#
#                        geometry_y   DIFF
# 18     POINT (-95.12007 29.54319)   86.0
# 19     POINT (-95.12605 29.53408)   86.0
# 225    POINT (-96.77919 32.78982)  120.0
# 226    POINT (-96.78031 32.79156)  128.0
# 227    POINT (-96.77919 32.78982)  128.0
# ...                           ...    ...
# 6333  POINT (-118.29013 34.09649)   60.0
# 6363  POINT (-117.15960 32.74969)   56.0
# 6446  POINT (-118.20149 34.06199)   64.0
# 6447  POINT (-118.20534 34.06151)  121.0
# 6818  POINT (-111.91881 33.48323)   59.0
#
# [115 rows x 56 columns]

# %%
matched_hcris = set(dh_hcris_df[~dh_hcris_df['Provider Number'].isnull()]['Provider Number'].values)

# %%
total_hcris = set(hcris_gdf['Provider Number'])

# %%
len(total_hcris - matched_hcris)
# Out:
# 348

# %%
hcris_gdf[hcris_gdf['Provider Number'].isin(total_hcris - matched_hcris)]
# Out:
#      Provider Number        FYB        FYE        STATUS  CTRL_TYPE  \
# 23            010035  01-JUL-18  30-JUN-19  As Submitted          9
# 32            010047  01-JAN-18  31-DEC-18  As Submitted          4
# 54            010089  01-JAN-18  31-DEC-18  As Submitted          1
# 67            010109  01-OCT-17  30-SEP-18  As Submitted          9
# 69            010112  01-OCT-17  30-SEP-18  As Submitted          8
# ...              ...        ...        ...           ...        ...
# 6565          670062  01-JAN-18  31-DEC-18  As Submitted          4
# 6586          670087  01-JAN-19  30-JUN-19  As Submitted          4
# 6607          670110  01-JAN-18  31-DEC-18  As Submitted          5
# 6615          670120  01-JAN-18  31-DEC-18  As Submitted          4
# 6617          670122  01-JAN-18  31-DEC-18  As Submitted          2
#
#                                HOSP10_Name                Street_Addr PO_Box  \
# 23                        CULLMAN REGIONAL   1912 ALABAMA HIGHWAY 157    NaN
# 32                      GEORGIANA HOSPITAL         515 MIRANDA STREET    NaN
# 54           WALKER BAPTIST MEDICAL CENTER       3400 HIGHWAY 78 EAST   3547
# 67           PICKENS COUNTY MEDICAL CENTER          R.K. WILSON DRIVE    NaN
# 69     BRYAN W WHITFIELD MEMORIAL HOSPITAL        105 HIGHWAY 80 EAST    NaN
# ...                                    ...                        ...    ...
# 6565       BAYLOR EMERGENCY MEDICAL CENTER              26791 HWY 380    NaN
# 6586              SCOTT & WHITE CEDAR PARK      900 E WHITESTONE BLVD    NaN
# 6607   FIRST TEXAS HOSPITAL CARROLLTON LLC  1401 E TRINITY MILLS ROAD    NaN
# 6615  HOSPITALS OF PROV TRANSMOUNTAIN CAMP         2000 TRANSMOUNTAIN    NaN
# 6617       HOUSTON METHODIST THE WOODLANDS        17201 INTERSTATE 45    NaN
#
#             City State Zip_Code      County  \
# 23       CULLMAN    AL    35056     CULLMAN
# 32     GEORGIANA    AL    36033      BUTLER
# 54        JASPER    AL    35502      WALKER
# 67    CARROLLTON    AL    35477     PICKENS
# 69     DEMOPOLIS    AL    36732     MARENGO
# ...          ...   ...      ...         ...
# 6565      AUBREY    TX    76227      DENTON
# 6586  CEDAR PARK    TX    78613  WILLIAMSON
# 6607  CARROLLTON    TX    75006      DALLAS
# 6615     EL PASO    TX    79911     EL PASO
# 6617  SHENANDOAH    TX    77385  MONTGOMERY
#
#       Hospital Adult and Peds Staffed Beds  \
# 23                                   133.0
# 32                                    22.0
# 54                                   195.0
# 67                                    36.0
# 69                                    32.0
# ...                                    ...
# 6565                                  40.0
# 6586                                   8.0
# 6607                                  18.0
# 6615                                  94.0
# 6617                                 130.0
#
#       Hospital Adult and Peds Bed Days Available  \
# 23                                       48545.0
# 32                                        8030.0
# 54                                       71175.0
# 67                                       13140.0
# 69                                       11680.0
# ...                                          ...
# 6565                                     13800.0
# 6586                                      2920.0
# 6607                                      6570.0
# 6615                                     34310.0
# 6617                                     47450.0
#
#       Hospital Adult and Peds Inpatient Days  \
# 23                                   23865.0
# 32                                    1391.0
# 54                                   18758.0
# 67                                    1945.0
# 69                                    3900.0
# ...                                      ...
# 6565                                  1235.0
# 6586                                    54.0
# 6607                                  1716.0
# 6615                                 14691.0
# 6617                                 18863.0
#
#       Intensive Care Unit Staffed Beds  \
# 23                                12.0
# 32                                 0.0
# 54                                12.0
# 67                                 4.0
# 69                                 5.0
# ...                                ...
# 6565                               0.0
# 6586                               0.0
# 6607                               0.0
# 6615                              12.0
# 6617                              16.0
#
#       Intensive Care Unit Bed Days Available  \
# 23                                    4380.0
# 32                                       0.0
# 54                                    4380.0
# 67                                    1460.0
# 69                                    1825.0
# ...                                      ...
# 6565                                     0.0
# 6586                                     0.0
# 6607                                     0.0
# 6615                                  4380.0
# 6617                                  5840.0
#
#       Intensive Care Unit Inpatient Days  Coronary Care Unit Staffed Beds  \
# 23                                3030.0                              0.0
# 32                                   0.0                              0.0
# 54                                2963.0                              0.0
# 67                                   0.0                              0.0
# 69                                 931.0                              0.0
# ...                                  ...                              ...
# 6565                                 0.0                              0.0
# 6586                                 0.0                              0.0
# 6607                                 0.0                              0.0
# 6615                              2179.0                              0.0
# 6617                              2912.0                              0.0
#
#       Coronary Care Unit Bed Days Available  \
# 23                                      0.0
# 32                                      0.0
# 54                                      0.0
# 67                                      0.0
# 69                                      0.0
# ...                                     ...
# 6565                                    0.0
# 6586                                    0.0
# 6607                                    0.0
# 6615                                    0.0
# 6617                                    0.0
#
#       Coronary Care Unit Inpatient Days  Burn ICU Staffed Beds  \
# 23                                  0.0                    0.0
# 32                                  0.0                    0.0
# 54                                  0.0                    0.0
# 67                                  0.0                    0.0
# 69                                  0.0                    0.0
# ...                                 ...                    ...
# 6565                                0.0                    0.0
# 6586                                0.0                    0.0
# 6607                                0.0                    0.0
# 6615                                0.0                    0.0
# 6617                                0.0                    0.0
#
#       Burn ICU Bed Days Available  Burn ICU Inpatient Days  \
# 23                            0.0                      0.0
# 32                            0.0                      0.0
# 54                            0.0                      0.0
# 67                            0.0                      0.0
# 69                            0.0                      0.0
# ...                           ...                      ...
# 6565                          0.0                      0.0
# 6586                          0.0                      0.0
# 6607                          0.0                      0.0
# 6615                          0.0                      0.0
# 6617                          0.0                      0.0
#
#       Surgical ICU Staffed Beds  Surgical ICU Bed Days Available  \
# 23                          0.0                              0.0
# 32                          0.0                              0.0
# 54                          0.0                              0.0
# 67                          0.0                              0.0
# 69                          0.0                              0.0
# ...                         ...                              ...
# 6565                        0.0                              0.0
# 6586                        0.0                              0.0
# 6607                        0.0                              0.0
# 6615                        0.0                              0.0
# 6617                        0.0                              0.0
#
#       Surgical ICU Inpatient Days  Total Staffed Beds  \
# 23                            0.0               145.0
# 32                            0.0                22.0
# 54                            0.0               207.0
# 67                            0.0                40.0
# 69                            0.0                37.0
# ...                           ...                 ...
# 6565                          0.0                40.0
# 6586                          0.0                 8.0
# 6607                          0.0                18.0
# 6615                          0.0               106.0
# 6617                          0.0               146.0
#
#       Total Bed Days Available  Total Inpatient Days  ICU Total Staffed Beds  \
# 23                     52925.0               26895.0                    12.0
# 32                      8030.0                1391.0                     0.0
# 54                     75555.0               23886.0                    12.0
# 67                     14600.0                2240.0                     4.0
# 69                     13505.0                6013.0                     5.0
# ...                        ...                   ...                     ...
# 6565                   13800.0                1235.0                     0.0
# 6586                    2920.0                  54.0                     0.0
# 6607                    6570.0                1716.0                     0.0
# 6615                   38690.0               17609.0                    12.0
# 6617                   53290.0               26721.0                    16.0
#
#       ICU Total Bed Days Available  ICU Total Inpatient Days  \
# 23                          4380.0                    3030.0
# 32                             0.0                       0.0
# 54                          4380.0                    2963.0
# 67                          1460.0                       0.0
# 69                          1825.0                     931.0
# ...                            ...                       ...
# 6565                           0.0                       0.0
# 6586                           0.0                       0.0
# 6607                           0.0                       0.0
# 6615                        4380.0                    2179.0
# 6617                        5840.0                    2912.0
#
#       ICU Occupancy Rate  Total Bed Occupancy Rate  \
# 23              0.691781                  0.508172
# 32                   NaN                  0.173225
# 54              0.676484                  0.316141
# 67              0.000000                  0.153425
# 69              0.510137                  0.445243
# ...                  ...                       ...
# 6565                 NaN                  0.089493
# 6586                 NaN                  0.018493
# 6607                 NaN                  0.261187
# 6615            0.497489                  0.455131
# 6617            0.498630                  0.501426
#
#                          geometry
# 23     POINT (-86.80550 34.20102)
# 32     POINT (-86.74305 31.63630)
# 54     POINT (-87.23600 33.84221)
# 67     POINT (-88.08826 33.27455)
# 69     POINT (-87.83642 32.50441)
# ...                           ...
# 6565   POINT (-96.91350 33.22067)
# 6586   POINT (-84.52222 36.39762)
# 6607   POINT (-96.89833 32.98571)
# 6615  POINT (-106.56504 31.90448)
# 6617   POINT (-95.45344 30.20578)
#
# [348 rows x 36 columns]

# %%
dh_gdf[dh_gdf['COUNTY_NAM'] == 'Cullman']
# Out:
#       OBJECTID                       HOSPITAL_N  \
# 2038        39  Cullman Regional Medical Center
# 6434      5855   The Sanctuary at the Woodlands
#
#                           HOSPITAL_T            HQ_ADDRESS HQ_ADDRE_1  \
# 2038  Short Term Acute Care Hospital  1912 Alabama Hwy 157       None
# 6434            Psychiatric Hospital     1910 Cherokee Ave       None
#
#       HQ_CITY HQ_STATE HQ_ZIP_COD COUNTY_NAM STATE_NAME STATE_FIPS CNTY_FIPS  \
# 2038  Cullman       AL      35058    Cullman    Alabama         01       043
# 6434  Cullman       AL      35055    Cullman    Alabama         01       043
#
#        FIPS  NUM_LICENS  NUM_STAFFE  NUM_ICU_BE  BED_UTILIZ  Potential_  \
# 2038  01043       145.0       145.0        12.0    0.508172           0
# 6434  01043        40.0        40.0         NaN    0.472329           0
#
#                         geometry
# 2038  POINT (-86.87485 34.20759)
# 6434  POINT (-86.84611 34.15099)

# %%
db_dh_hcris[db_dh_hcris['left__OBJECTID'] == 86]
# Out:
#                       left__geometry  left__OBJECTID  \
# 2085  POINT (909618.389 1074816.266)              86
#
#                   left__HOSPITAL_N   left__HQ_ADDRESS  \
# 2085  Baptist Medical Center South  2105 E South Blvd
#
#                                                geometry  \
# 2085  POLYGON ((909768.389 1074816.266, 909767.666 1...
#
#                       point_geometry  index_right right__geometry  \
# 2085  POINT (909618.389 1074816.266)          NaN            None
#
#      right__Provider Number right__HOSP10_Name right__Street_Addr  similarity
# 2085                    NaN                NaN                NaN         0.0

# %%
db_dh_hcris[db_dh_hcris['right__Provider Number'] == '010023']
# Out:
# Empty GeoDataFrame
# Columns: [left__geometry, left__OBJECTID, left__HOSPITAL_N, left__HQ_ADDRESS, geometry, point_geometry, index_right, right__geometry, right__Provider Number, right__HOSP10_Name, right__Street_Addr, similarity]
# Index: []

# %% [markdown]
# #### Attempt using full outer join

# %%
joined_hcris_hifld, db_hcris_hifld = spatial_join_facilities(left=hifld_filtered_gdf,
                        right=hcris_filtered_gdf,
                        lid_property = id_columns['HIFLD'],
                        rid_property = id_columns['HCRIS'],
                        lsimilarity_properties = similarity_columns['HIFLD'],
                        rsimilarity_properties = similarity_columns['HCRIS'],
                        similarity_weights=[0.6, 0.4],
                        distance=50)

# %%
joined_hifld_dh, db_hifld_dh = spatial_join_facilities(left=hifld_filtered_gdf,
                        right=dh_filtered_gdf,
                        lid_property = id_columns['HIFLD'],
                        rid_property = id_columns['DH'],
                        lsimilarity_properties = similarity_columns['HIFLD'],
                        rsimilarity_properties = similarity_columns['DH'],
                        similarity_weights=[0.6, 0.4],
                        distance=50)

# %%
joined_hcris_dh, db_hcris_dh = spatial_join_facilities(left=hcris_filtered_gdf,
                        right=dh_filtered_gdf,
                        lid_property = id_columns['HCRIS'],
                        rid_property = id_columns['DH'],
                        lsimilarity_properties = similarity_columns['HCRIS'],
                        rsimilarity_properties = similarity_columns['DH'],
                        similarity_weights=[0.6, 0.4],
                        distance=50)

# %% [markdown]
# ## Match validation
#
# Check the transitive matching between the 3 different joins as a sanity check.

# %%
matched_hcris_hifld = joined_hcris_hifld.dropna()
matched_hifld_dh = joined_hifld_dh.dropna()
matched_hcris_dh = joined_hcris_dh.dropna()

# %%
matched_hcris_hifld_dh = \
    matched_hcris_hifld.merge(matched_hifld_dh, how='inner', on=id_columns['HIFLD'])
matched_hcris_hifld_dh_hcris = \
    matched_hcris_hifld_dh.merge(matched_hcris_dh, how='inner', on=id_columns['DH'])

# %%
matched_hcris_hifld_dh_hcris[matched_hcris_hifld_dh_hcris['Provider Number_x'] != matched_hcris_hifld_dh_hcris['Provider Number_y']]
# Out:
#                ID Provider Number_x  OBJECTID Provider Number_y
# 16     49175092.0            673041    5182.0            452041
# 25      5377702.0            673030    5131.0            450034
# 28      5377702.0            450034    4412.0            673030
# 29      5377702.0            673030    3735.0            450034
# 80      8453227.0            520139    4871.0            522006
# 81      8453227.0            522006    4180.0            520139
# 185    12707450.0            500119    2473.0            310012
# 284   136979905.0            450024    5732.0            453313
# 314    45778205.0            452073    5024.0            450058
# 315    45778205.0            452073    3572.0            450058
# 414    53975711.0            450083    4654.0            452051
# 415    53975711.0            450083    3796.0            452051
# 430     4937061.0            441322    3503.0            440232
# 542     9015650.0            390219    5538.0            392036
# 707   123145216.0            363034    5928.0            362004
# 709   123145216.0            363034    5329.0            362004
# 715   128145342.0            360239    4466.0            362028
# 717   128145342.0            360239    2980.0            362028
# 816     4528256.0            340166    6313.0            342021
# 920     3988011.0            322004    5184.0            323032
# 941     9408724.0            310052    4673.0            313033
# 942     9408724.0            313033    2515.0            310052
# 1066    2465201.0            263033    6551.0            262020
# 1068    2465201.0            263033    2184.0            262020
# 1078   11263301.0            260005    4725.0            262013
# 1079   11263301.0            262013    2249.0            260005
# 1117    8039183.0            252008    2169.0            250031
# 1205   17648342.0            230207    6146.0            232039
# 1206   17648342.0            232039    1919.0            230207
# 1208    2248912.0            232037    5386.0            230230
# 1210    2248912.0            232037    1883.0            230230
# 1214     549017.0            232035    1858.0            230075
# 1219    1348532.0            230141    5526.0            232012
# 1220    1348532.0            232012    1873.0            230141
# 1369   15070809.0            192004    5706.0            192049
# 1376    5270601.0            190027    4817.0            192019
# 1378    5270601.0            190027    1630.0            192019
# 1429   10942101.0            180013    5475.0            182005
# 1430   10942101.0            182005    1613.0            180013
# 1433    9040509.0            182002    1549.0            180143
# 1468   14667214.0            170122    5471.0            172007
# 1470   14667214.0            170122    1505.0            172007
# 1531   92950314.0            160083    6157.0            162003
# 1533   92950314.0            160083    1390.0            162003
# 1781   84031412.0            112011     884.0            110024
# 1834   20533301.0            104026    4823.0            102010
# 2034   25992354.0            050778    5747.0            050327
# 2036   25992354.0            050778     467.0            050327
# 2143    7900000.0            040137    5266.0            043031
# 2144    7900000.0            043031     246.0            040137
# 2148   61472401.0            042013    6276.0            040155
# 2152    2972764.0            042009     259.0            040022
# 2192    8485006.0            030037    4475.0            034013

# %%
hcris_gdf[hcris_gdf['Provider Number'] == '673041']
# Out:
#      Provider Number        FYB        FYE        STATUS  CTRL_TYPE  \
# 6634          673041  01-AUG-18  31-JUL-19  As Submitted          5
#
#                          HOSP10_Name                Street_Addr PO_Box  \
# 6634  CARRUS REHABILITATION HOSPITAL  1810 U.S. HIGHWAY 82 WEST    NaN
#
#          City State  ... Surgical ICU Inpatient Days Total Staffed Beds  \
# 6634  SHERMAN    TX  ...                         0.0               24.0
#
#       Total Bed Days Available  Total Inpatient Days  ICU Total Staffed Beds  \
# 6634                    8760.0                8300.0                     0.0
#
#       ICU Total Bed Days Available  ICU Total Inpatient Days  \
# 6634                           0.0                       0.0
#
#       ICU Occupancy Rate  Total Bed Occupancy Rate                    geometry
# 6634                 NaN                  0.947489  POINT (-96.63464 33.66985)
#
# [1 rows x 36 columns]

# %%
hifld_gdf[hifld_gdf['ID'] == 49175092.0]
# Out:
#               X          Y  OBJECTID        ID                       NAME  \
# 2715 -96.634386  33.669726      4135  49175092  CARRUS SPECIALTY HOSPITAL
#
#                                  ADDRESS     CITY STATE    ZIP           ZIP4  \
# 2715  1810 U.S. HIGHWAY 82 WEST, STE 200  SHERMAN    TX  75092  NOT AVAILABLE
#
#       ...                                            WEBSITE       STATE_ID  \
# 2715  ...  http://www.carrushospital.com/carrus-specialty...  NOT AVAILABLE
#
#            ALT_NAME  ST_FIPS        OWNER TTL_STAFF BEDS         TRAUMA  \
# 2715  NOT AVAILABLE       48  PROPRIETARY      -999   16  NOT AVAILABLE
#
#       HELIPAD                    geometry
# 2715        N  POINT (-96.63439 33.66973)
#
# [1 rows x 35 columns]

# %%
dh_gdf[dh_gdf['OBJECTID'] == 5182.0]
# Out:
#       OBJECTID                 HOSPITAL_N                     HOSPITAL_T  \
# 5761      5182  Carrus Specialty Hospital  Long Term Acute Care Hospital
#
#                 HQ_ADDRESS HQ_ADDRE_1  HQ_CITY HQ_STATE HQ_ZIP_COD COUNTY_NAM  \
# 5761  1810 W Us Highway 82       None  Sherman       TX      75092    Grayson
#
#      STATE_NAME STATE_FIPS CNTY_FIPS   FIPS  NUM_LICENS  NUM_STAFFE  \
# 5761      Texas         48       181  48181        16.0        24.0
#
#       NUM_ICU_BE  BED_UTILIZ  Potential_                    geometry
# 5761         9.0    0.792122          -8  POINT (-96.63467 33.66980)

# %%
hcris_gdf[hcris_gdf['Provider Number'] == '452041']
# Out:
#      Provider Number        FYB        FYE        STATUS  CTRL_TYPE  \
# 5799          452041  01-JAN-18  31-DEC-18  As Submitted          5
#
#                     HOSP10_Name           Street_Addr PO_Box     City State  \
# 5799  CARRUS SPECIALTY HOSPITAL  1810 WEST HIGHWAY 82    NaN  SHERMAN    TX
#
#       ... Surgical ICU Inpatient Days Total Staffed Beds  \
# 5799  ...                         0.0               24.0
#
#       Total Bed Days Available  Total Inpatient Days  ICU Total Staffed Beds  \
# 5799                    8962.0                7099.0                     9.0
#
#       ICU Total Bed Days Available  ICU Total Inpatient Days  \
# 5799                        3653.0                    2583.0
#
#       ICU Occupancy Rate  Total Bed Occupancy Rate                    geometry
# 5799             0.70709                  0.792122  POINT (-96.63464 33.66985)
#
# [1 rows x 36 columns]

# %%
db_hcris_hifld
# Out:
#                        left__geometry left__Provider Number  \
# 0      POINT (1008037.577 960958.594)                010001
# 1      POINT (898093.066 1286259.533)                010005
# 2      POINT (756681.066 1338177.650)                010006
# 3       POINT (922986.951 960315.135)                010007
# 4      POINT (917418.801 1004685.742)                010008
# ...                               ...                   ...
# 6655  POINT (-166540.138 1077041.038)                673062
# 6657   POINT (-99994.973 1107804.552)                673064
# 6658    POINT (-33522.349 842778.645)                673065
# 6659     POINT (59085.361 722213.392)                673066
# 6660   POINT (-138061.823 525728.067)                673067
#
#                          left__HOSP10_Name            left__Street_Addr  \
# 0          SOUTHEAST HEALTH MEDICAL CENTER       1108 ROSS CLARK CIRCLE
# 1          MARSHALL MEDICAL CENTER - SOUTH        2505 U.S. HIGHWAY 431
# 2             NORTH ALABAMA MEDICAL CENTER          1701 VETERANS DRIVE
# 3                 MIZELL MEMORIAL HOSPITAL              702 MAIN STREET
# 4              CRENSHAW COMMUNITY HOSPITAL  CRENSHAW COMMUNITY HOSPITAL
# ...                                    ...                          ...
# 6655    WEATHERFORD REABILITATION HOSPITAL                703 EUREKA ST
# 6657         ICARE REHABILITATION HOSPITAL      3100 PETERS COLONY ROAD
# 6658  CHI ST. JOSEPH HEALTH REHABILITATION            1600 JOSEPH DRIVE
# 6659  ENCOMPASS HEALTH REHABILITATION HOSP   2121 BUSINESS CENTER DRIVE
# 6660     PAM REHAB HOSPITAL CORPUS CHRISTI          345 S. WATER STREET
#
#                                                geometry  \
# 0     POLYGON ((1008087.577 960958.594, 1008087.337 ...
# 1     POLYGON ((898143.066 1286259.533, 898142.825 1...
# 2     POLYGON ((756731.066 1338177.650, 756730.825 1...
# 3     POLYGON ((923036.951 960315.135, 923036.711 96...
# 4     POLYGON ((917468.801 1004685.742, 917468.560 1...
# ...                                                 ...
# 6655  POLYGON ((-166490.138 1077041.038, -166490.379...
# 6657  POLYGON ((-99944.973 1107804.552, -99945.214 1...
# 6658  POLYGON ((-33472.349 842778.645, -33472.589 84...
# 6659  POLYGON ((59135.361 722213.392, 59135.120 7222...
# 6660  POLYGON ((-138011.823 525728.067, -138012.063 ...
#
#                        point_geometry  index_right  \
# 0      POINT (1008037.577 960958.594)          NaN
# 1      POINT (898093.066 1286259.533)          NaN
# 2      POINT (756681.066 1338177.650)          NaN
# 3       POINT (922986.951 960315.135)       4882.0
# 4      POINT (917418.801 1004685.742)       6193.0
# ...                               ...          ...
# 6655  POINT (-166540.138 1077041.038)        503.0
# 6657   POINT (-99994.973 1107804.552)       1474.0
# 6658    POINT (-33522.349 842778.645)          NaN
# 6659     POINT (59085.361 722213.392)          NaN
# 6660   POINT (-138061.823 525728.067)          NaN
#
#                       right__geometry    right__ID  \
# 0                                None          NaN
# 1                                None          NaN
# 2                                None          NaN
# 3       POINT (922953.236 960308.917)    5636467.0
# 4      POINT (917389.348 1004674.818)    3536049.0
# ...                               ...          ...
# 6655  POINT (-166539.590 1077034.680)   79776086.0
# 6657   POINT (-99997.410 1107807.569)  135275022.0
# 6658                             None          NaN
# 6659                             None          NaN
# 6660                             None          NaN
#
#                                   right__NAME           right__ADDRESS  \
# 0                                         NaN                      NaN
# 1                                         NaN                      NaN
# 2                                         NaN                      NaN
# 3                    MIZELL MEMORIAL HOSPITAL          702 MAIN STREET
# 4                 CRENSHAW COMMUNITY HOSPITAL      101 HOSPITAL CIRCLE
# ...                                       ...                      ...
# 6655  WEATHERFORD REHABILITATION HOSPITAL LLC            703 EUREKA ST
# 6657             ICARE REHABILTATION HOSPITAL  3100 PETERS COLONY ROAD
# 6658                                      NaN                      NaN
# 6659                                      NaN                      NaN
# 6660                                      NaN                      NaN
#
#       similarity
# 0       0.000000
# 1       0.000000
# 2       0.000000
# 3       1.000000
# 4       0.756522
# ...          ...
# 6655    0.958904
# 6657    0.989474
# 6658    0.000000
# 6659    0.000000
# 6660    0.000000
#
# [5633 rows x 12 columns]

# %%
db_hcris_hifld[db_hcris_hifld['right__Provider Number'] == '673041']
# Out:
#                       left__geometry  left__ID                 left__NAME  \
# 2715  POINT (-58415.224 1178268.484)  49175092  CARRUS SPECIALTY HOSPITAL
#
#                            left__ADDRESS  \
# 2715  1810 U.S. HIGHWAY 82 WEST, STE 200
#
#                                                geometry  \
# 2715  POLYGON ((-58365.224 1178268.484, -58365.465 1...
#
#                       point_geometry  index_right  \
# 2715  POINT (-58415.224 1178268.484)       6634.0
#
#                      right__geometry right__Provider Number  \
# 2715  POINT (-58438.350 1178282.014)                 673041
#
#                   right__HOSP10_Name         right__Street_Addr  similarity
# 2715  CARRUS REHABILITATION HOSPITAL  1810 U.S. HIGHWAY 82 WEST        77.8

# %%
db_hcris_dh
# Out:
#                        left__geometry left__Provider Number  \
# 0      POINT (1008037.577 960958.594)                010001
# 1      POINT (898093.066 1286259.533)                010005
# 2      POINT (756681.066 1338177.650)                010006
# 3       POINT (922986.951 960315.135)                010007
# 4      POINT (917418.801 1004685.742)                010008
# ...                               ...                   ...
# 6655  POINT (-166540.138 1077041.038)                673062
# 6657   POINT (-99994.973 1107804.552)                673064
# 6658    POINT (-33522.349 842778.645)                673065
# 6659     POINT (59085.361 722213.392)                673066
# 6660   POINT (-138061.823 525728.067)                673067
#
#                          left__HOSP10_Name            left__Street_Addr  \
# 0          SOUTHEAST HEALTH MEDICAL CENTER       1108 ROSS CLARK CIRCLE
# 1          MARSHALL MEDICAL CENTER - SOUTH        2505 U.S. HIGHWAY 431
# 2             NORTH ALABAMA MEDICAL CENTER          1701 VETERANS DRIVE
# 3                 MIZELL MEMORIAL HOSPITAL              702 MAIN STREET
# 4              CRENSHAW COMMUNITY HOSPITAL  CRENSHAW COMMUNITY HOSPITAL
# ...                                    ...                          ...
# 6655    WEATHERFORD REABILITATION HOSPITAL                703 EUREKA ST
# 6657         ICARE REHABILITATION HOSPITAL      3100 PETERS COLONY ROAD
# 6658  CHI ST. JOSEPH HEALTH REHABILITATION            1600 JOSEPH DRIVE
# 6659  ENCOMPASS HEALTH REHABILITATION HOSP   2121 BUSINESS CENTER DRIVE
# 6660     PAM REHAB HOSPITAL CORPUS CHRISTI          345 S. WATER STREET
#
#                                                geometry  \
# 0     POLYGON ((1008087.577 960958.594, 1008087.337 ...
# 1     POLYGON ((898143.066 1286259.533, 898142.825 1...
# 2     POLYGON ((756731.066 1338177.650, 756730.825 1...
# 3     POLYGON ((923036.951 960315.135, 923036.711 96...
# 4     POLYGON ((917468.801 1004685.742, 917468.560 1...
# ...                                                 ...
# 6655  POLYGON ((-166490.138 1077041.038, -166490.379...
# 6657  POLYGON ((-99944.973 1107804.552, -99945.214 1...
# 6658  POLYGON ((-33472.349 842778.645, -33472.589 84...
# 6659  POLYGON ((59135.361 722213.392, 59135.120 7222...
# 6660  POLYGON ((-138011.823 525728.067, -138012.063 ...
#
#                        point_geometry  index_right  \
# 0      POINT (1008037.577 960958.594)       5920.0
# 1      POINT (898093.066 1286259.533)       2076.0
# 2      POINT (756681.066 1338177.650)       2067.0
# 3       POINT (922986.951 960315.135)       2036.0
# 4      POINT (917418.801 1004685.742)       2037.0
# ...                               ...          ...
# 6655  POINT (-166540.138 1077041.038)       5248.0
# 6657   POINT (-99994.973 1107804.552)       6565.0
# 6658    POINT (-33522.349 842778.645)       5227.0
# 6659     POINT (59085.361 722213.392)       5281.0
# 6660   POINT (-138061.823 525728.067)       5420.0
#
#                       right__geometry  right__OBJECTID  \
# 0      POINT (1007992.701 960950.449)           5341.0
# 1      POINT (898051.208 1286276.998)             77.0
# 2      POINT (756681.066 1338177.650)             68.0
# 3       POINT (922983.196 960315.017)             37.0
# 4      POINT (917386.979 1004653.175)             38.0
# ...                               ...              ...
# 6655  POINT (-166542.462 1077032.423)           6249.0
# 6657   POINT (-99987.722 1107801.289)           5986.0
# 6658    POINT (-33549.860 842759.521)           6228.0
# 6659     POINT (59083.064 722211.925)           6282.0
# 6660   POINT (-138071.909 525730.633)           6421.0
#
#                                       right__HOSPITAL_N  \
# 0                                Noland Hospital Dothan
# 1                         Marshall Medical Center South
# 2     North Alabama Medical Center (FKA Eliza Coffee...
# 3                              Mizell Memorial Hospital
# 4                           Crenshaw Community Hospital
# ...                                                 ...
# 6655                Weatherford Rehabilitation Hospital
# 6657  iCare Rehabilitation Hospital & Physical Medic...
# 6658       CHI St Joseph Health Rehabilitation Hospital
# 6659  Encompass Health Rehabilitation Hospital of Pe...
# 6660  PAM Rehabilitation Hospital and LTACH of Corpu...
#
#             right__HQ_ADDRESS  similarity
# 0         1108 Ross Clark Cir    0.285688
# 1         2505 Us Highway 431    0.380000
# 2            1701 Veterans Dr    0.298986
# 3               702 N Main St    0.325000
# 4             101 Hospital Dr    0.149206
# ...                       ...         ...
# 6655            703 Eureka St    0.302341
# 6657    3100 Peters Colony Rd    0.241818
# 6658           1600 Joseph Dr    0.386452
# 6659  2121 Business Center Dr    0.240963
# 6660           345 S Water St    0.395455
#
# [5689 rows x 12 columns]

# %%
db_hcris_dh[db_hcris_dh['left__Provider Number'] == '450539']
# Out:
#                        left__geometry left__Provider Number  \
# 5565  POINT (-523938.620 1253873.506)                450539
# 5565  POINT (-523938.620 1253873.506)                450539
#
#                 left__HOSP10_Name  left__Street_Addr  \
# 5565  COVENANT HOSPITAL PLAINVIEW  2601 DIMMITT ROAD
# 5565  COVENANT HOSPITAL PLAINVIEW  2601 DIMMITT ROAD
#
#                                                geometry  \
# 5565  POLYGON ((-523913.620 1253873.506, -523913.740...
# 5565  POLYGON ((-523913.620 1253873.506, -523913.740...
#
#                        point_geometry  index_right  \
# 5565  POINT (-523938.620 1253873.506)       5746.0
# 5565  POINT (-523938.620 1253873.506)       3679.0
#
#                       right__geometry  right__OBJECTID  \
# 5565  POINT (-523938.564 1253873.525)           5167.0
# 5565  POINT (-523938.564 1253873.525)           3680.0
#
#                                      right__HOSPITAL_N right__HQ_ADDRESS  \
# 5565  Allegiance Behavioral Health Center of Plainview   2601 Dimmitt Rd
# 5565                         Covenant Health Plainview   2601 Dimmitt Rd
#
#       similarity
# 5565    0.280000
# 5565    0.315385

# %%
hcris_gdf[hcris_gdf['Provider Number'] == '362004']
# Out:
#      Provider Number        FYB        FYE        STATUS  CTRL_TYPE  \
# 4459          362004  01-JUL-18  30-JUN-19  As Submitted          2
#
#                                HOSP10_Name              Street_Addr PO_Box  \
# 4459  DANIEL DRAKE CENTER FOR POST-ACUTE C  151 WEST GALBRAITH ROAD    NaN
#
#             City State  ... Surgical ICU Inpatient Days Total Staffed Beds  \
# 4459  CINCINNATI    OH  ...                         0.0              108.0
#
#       Total Bed Days Available  Total Inpatient Days  ICU Total Staffed Beds  \
# 4459                   39420.0               16523.0                     0.0
#
#       ICU Total Bed Days Available  ICU Total Inpatient Days  \
# 4459                           0.0                       0.0
#
#       ICU Occupancy Rate  Total Bed Occupancy Rate                    geometry
# 4459                 NaN                  0.419153  POINT (-84.48030 39.21246)
#
# [1 rows x 36 columns]

# %%
hcris_gdf[hcris_gdf['Provider Number'] == '363037']
# Out:
#      Provider Number        FYB        FYE        STATUS  CTRL_TYPE  \
# 4491          363037  01-JUL-18  30-JUN-19  As Submitted          4
#
#                              HOSP10_Name                  Street_Addr PO_Box  \
# 4491  OHIOHEALTH REHABILITATION HOSPITAL  1087 DENNISON AVE 4TH FLOOR    NaN
#
#           City State  ... Surgical ICU Inpatient Days Total Staffed Beds  \
# 4491  COLUMBUS    OH  ...                         0.0               74.0
#
#       Total Bed Days Available  Total Inpatient Days  ICU Total Staffed Beds  \
# 4491                   27010.0               20847.0                     0.0
#
#       ICU Total Bed Days Available  ICU Total Inpatient Days  \
# 4491                           0.0                       0.0
#
#       ICU Occupancy Rate  Total Bed Occupancy Rate                    geometry
# 4491                 NaN                  0.771825  POINT (-83.00886 39.98438)
#
# [1 rows x 36 columns]

# %%
dh_gdf[dh_gdf['OBJECTID'] == 5329.0]
# Out:
#       OBJECTID           HOSPITAL_N                     HOSPITAL_T  \
# 5908      5329  Daniel Drake Center  Long Term Acute Care Hospital
#
#               HQ_ADDRESS HQ_ADDRE_1     HQ_CITY HQ_STATE HQ_ZIP_COD  \
# 5908  151 W Galbraith Rd       None  Cincinnati       OH      45216
#
#      COUNTY_NAM STATE_NAME STATE_FIPS CNTY_FIPS   FIPS  NUM_LICENS  \
# 5908   Hamilton       Ohio         39       061  39061       108.0
#
#       NUM_STAFFE  NUM_ICU_BE  BED_UTILIZ  Potential_  \
# 5908       108.0         NaN    0.419153           0
#
#                         geometry
# 5908  POINT (-84.48030 39.21272)

# %%
dh_gdf[dh_gdf['OBJECTID'] == 5928.0]
# Out:
#       OBJECTID                                         HOSPITAL_N  \
# 6507      5928  Encompass Health Rehabilitation Hospital of Ci...
#
#                    HOSPITAL_T          HQ_ADDRESS HQ_ADDRE_1     HQ_CITY  \
# 6507  Rehabilitation Hospital  151 W Galbraith Rd       None  Cincinnati
#
#      HQ_STATE HQ_ZIP_COD COUNTY_NAM STATE_NAME STATE_FIPS CNTY_FIPS   FIPS  \
# 6507       OH      45216   Hamilton       Ohio         39       061  39061
#
#       NUM_LICENS  NUM_STAFFE  NUM_ICU_BE  BED_UTILIZ  Potential_  \
# 6507        60.0        60.0         NaN    0.668466           0
#
#                         geometry
# 6507  POINT (-84.48017 39.21244)

# %%
matched_hifld_dh
# Out:
#                ID  OBJECTID
# 403    25477008.0    6578.0
# 1893   10437604.0    6568.0
# 4236   84530533.0    6552.0
# 6628    2465201.0    6551.0
# 5238  103120912.0    6550.0
# ...           ...       ...
# 6955    9687108.0      12.0
# 3746    5739296.0      10.0
# 2453    2183702.0       8.0
# 2592  173319805.0       5.0
# 4001     185012.0       1.0
#
# [2215 rows x 2 columns]

# %%
hifld_gdf[hifld_gdf['ID'] == 11036301.0]
# Out:
#               X          Y  OBJECTID        ID  \
# 1495 -85.363631  31.216304       915  11036301
#
#                                   NAME                 ADDRESS    CITY STATE  \
# 1495  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE  DOTHAN    AL
#
#         ZIP           ZIP4  ...              WEBSITE STATE_ID       ALT_NAME  \
# 1495  36301  NOT AVAILABLE  ...  http://www.samc.org    H3502  NOT AVAILABLE
#
#       ST_FIPS                            OWNER TTL_STAFF BEDS    TRAUMA  \
# 1495        1  GOVERNMENT - DISTRICT/AUTHORITY      -999  420  LEVEL II
#
#       HELIPAD                    geometry
# 1495        Y  POINT (-85.36363 31.21630)
#
# [1 rows x 35 columns]

# %%
hcris_gdf[hcris_gdf['Provider Number'] == '010001']
# Out:
#   Provider Number        FYB        FYE        STATUS  CTRL_TYPE  \
# 0          010001  01-OCT-17  30-SEP-18  As Submitted          9
#
#                        HOSP10_Name             Street_Addr PO_Box    City  \
# 0  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE   6987  DOTHAN
#
#   State  ... Surgical ICU Inpatient Days Total Staffed Beds  \
# 0    AL  ...                         0.0              327.0
#
#    Total Bed Days Available  Total Inpatient Days  ICU Total Staffed Beds  \
# 0                  119355.0               95560.0                    40.0
#
#    ICU Total Bed Days Available  ICU Total Inpatient Days  ICU Occupancy Rate  \
# 0                       14600.0                   11992.0             0.82137
#
#    Total Bed Occupancy Rate                    geometry
# 0                  0.800637  POINT (-85.36253 31.21591)
#
# [1 rows x 36 columns]

# %%
hcris_gdf[hcris_gdf['Provider Number'] == '012010']
# Out:
#     Provider Number        FYB        FYE        STATUS  CTRL_TYPE  \
# 107          012010  01-SEP-17  31-AUG-18  As Submitted          2
#
#                    HOSP10_Name                       Street_Addr PO_Box  \
# 107  NOLAND HOSPITAL DOTHAN II  1180 ROSS CLARK CIRCLE 4TH FLOOR    NaN
#
#        City State  ... Surgical ICU Inpatient Days Total Staffed Beds  \
# 107  DOTHAN    AL  ...                         0.0                0.0
#
#      Total Bed Days Available  Total Inpatient Days  ICU Total Staffed Beds  \
# 107                       0.0                   0.0                     0.0
#
#      ICU Total Bed Days Available  ICU Total Inpatient Days  \
# 107                           0.0                       0.0
#
#      ICU Occupancy Rate  Total Bed Occupancy Rate                    geometry
# 107                 0.0                       0.0  POINT (-85.36307 31.21673)
#
# [1 rows x 36 columns]

# %%
joined_hcris_hifld[joined_hcris_hifld['ID'] == 11036301.0]
# Out:
#   Provider Number          ID
# 0          010001  11036301.0

# %%
x = joined_hcris_hifld.drop_duplicates('ID')

# %%
x[x['ID'] == 11036301.0]
# Out:
#   Provider Number          ID
# 0          010001  11036301.0

# %%
matched_hcris_hifld
# Out:
#      Provider Number           ID
# 0             010001   11036301.0
# 0             010001   91336302.0
# 1             010005    9135957.0
# 3             010007    5636467.0
# 4             010008    3536049.0
# ...              ...          ...
# 6654          673061   77477598.0
# 6655          673062   79776086.0
# 6656          673063   36279415.0
# 6657          673064  135275022.0
# 6658          673065    8877802.0
#
# [6513 rows x 2 columns]

# %%
joined_hcris_hifld
# Out:
#      Provider Number           ID
# 239           031308  181585247.0
# 4686          373035  180374133.0
# 4422          360364  180044011.0
# 3601          283026  179968118.0
# 948           064027  178680534.0
# ...              ...          ...
# 7576             NaN  110408244.0
# 7577             NaN  110508536.0
# 7578             NaN  123244024.0
# 7579             NaN    4587102.0
# 7580             NaN    6600738.0
#
# [7582 rows x 2 columns]

# %%
matched_hcris_hifld
# Out:
#      Provider Number           ID
# 239           031308  181585247.0
# 4686          373035  180374133.0
# 4422          360364  180044011.0
# 3601          283026  179968118.0
# 948           064027  178680534.0
# ...              ...          ...
# 4922          390328        110.0
# 4386          360211         99.0
# 3175          250038         84.0
# 5378          442014         81.0
# 3594          281364         63.0
#
# [2026 rows x 2 columns]

# %%
matched_hcris_dh
# Out:
#      Provider Number  OBJECTID
# 0             010001    5341.0
# 1             010005      77.0
# 2             010006      68.0
# 3             010007      37.0
# 4             010008      38.0
# ...              ...       ...
# 6656          673063    3755.0
# 6657          673064    5986.0
# 6658          673065    6228.0
# 6659          673066    6282.0
# 6660          673067    6421.0
#
# [5690 rows x 2 columns]

# %%
hcris_gdf.columns
# Out:
# Index(['Provider Number', 'FYB', 'FYE', 'STATUS', 'CTRL_TYPE', 'HOSP10_Name',
#        'Street_Addr', 'PO_Box', 'City', 'State', 'Zip_Code', 'County',
#        'Hospital Adult and Peds Staffed Beds',
#        'Hospital Adult and Peds Bed Days Available',
#        'Hospital Adult and Peds Inpatient Days',
#        'Intensive Care Unit Staffed Beds',
#        'Intensive Care Unit Bed Days Available',
#        'Intensive Care Unit Inpatient Days', 'Coronary Care Unit Staffed Beds',
#        'Coronary Care Unit Bed Days Available',
#        'Coronary Care Unit Inpatient Days', 'Burn ICU Staffed Beds',
#        'Burn ICU Bed Days Available', 'Burn ICU Inpatient Days',
#        'Surgical ICU Staffed Beds', 'Surgical ICU Bed Days Available',
#        'Surgical ICU Inpatient Days', 'Total Staffed Beds',
#        'Total Bed Days Available', 'Total Inpatient Days',
#        'ICU Total Staffed Beds', 'ICU Total Bed Days Available',
#        'ICU Total Inpatient Days', 'ICU Occupancy Rate',
#        'Total Bed Occupancy Rate', 'geometry'],
#       dtype='object')

# %%
hcris_gdf.columns
# Out:
# Index(['Provider Number', 'FYB', 'FYE', 'STATUS', 'CTRL_TYPE', 'HOSP10_Name',
#        'Street_Addr', 'PO_Box', 'City', 'State', 'Zip_Code', 'County',
#        'Hospital Adult and Peds Staffed Beds',
#        'Hospital Adult and Peds Bed Days Available',
#        'Hospital Adult and Peds Inpatient Days',
#        'Intensive Care Unit Staffed Beds',
#        'Intensive Care Unit Bed Days Available',
#        'Intensive Care Unit Inpatient Days', 'Coronary Care Unit Staffed Beds',
#        'Coronary Care Unit Bed Days Available',
#        'Coronary Care Unit Inpatient Days', 'Burn ICU Staffed Beds',
#        'Burn ICU Bed Days Available', 'Burn ICU Inpatient Days',
#        'Surgical ICU Staffed Beds', 'Surgical ICU Bed Days Available',
#        'Surgical ICU Inpatient Days', 'Total Staffed Beds',
#        'Total Bed Days Available', 'Total Inpatient Days',
#        'ICU Total Staffed Beds', 'ICU Total Bed Days Available',
#        'ICU Total Inpatient Days', 'ICU Occupancy Rate',
#        'Total Bed Occupancy Rate', 'geometry'],
#       dtype='object')

# %%
joined_hcris_hifld
# Out:
#      Provider Number           ID
# 0             010001   11036301.0
# 0             010001   91336302.0
# 1             010005    9135957.0
# 2             010006          NaN
# 3             010007    5636467.0
# ...              ...          ...
# 7568             NaN    4608755.0
# 7574             NaN  109207207.0
# 7575             NaN  109908818.0
# 7579             NaN    4587102.0
# 7580             NaN    6600738.0
#
# [9169 rows x 2 columns]

# %%
joined_hifld_dh
# Out:
#               ID  OBJECTID
# 0      3829406.0    4664.0
# 1     11029303.0    6041.0
# 2      2929505.0       NaN
# 3      1298816.0    4005.0
# 4       324450.0    3978.0
# ...          ...       ...
# 6562         NaN    5983.0
# 6572         NaN    5993.0
# 6576         NaN    5997.0
# 6578         NaN    5999.0
# 6579         NaN    6000.0
#
# [9362 rows x 2 columns]

# %%
joined_hcris_dh
# Out:
#      Provider Number  OBJECTID
# 0             010001    5341.0
# 1             010005      77.0
# 2             010006      68.0
# 3             010007      37.0
# 4             010008      38.0
# ...              ...       ...
# 6575             NaN    5996.0
# 6576             NaN    5997.0
# 6577             NaN    5998.0
# 6578             NaN    5999.0
# 6579             NaN    6000.0
#
# [8626 rows x 2 columns]

# %%
dh_gdf.columns
# Out:
# Index(['OBJECTID', 'HOSPITAL_N', 'HOSPITAL_T', 'HQ_ADDRESS', 'HQ_ADDRE_1',
#        'HQ_CITY', 'HQ_STATE', 'HQ_ZIP_COD', 'COUNTY_NAM', 'STATE_NAME',
#        'STATE_FIPS', 'CNTY_FIPS', 'FIPS', 'NUM_LICENS', 'NUM_STAFFE',
#        'NUM_ICU_BE', 'BED_UTILIZ', 'Potential_', 'geometry'],
#       dtype='object')

# %%
hcris_gdf.count()
# Out:
# Provider Number                               6661
# FYB                                           6661
# FYE                                           6661
# STATUS                                        6661
# CTRL_TYPE                                     6661
# HOSP10_Name                                   6661
# Street_Addr                                   6661
# PO_Box                                        6661
# City                                          6661
# State                                         6661
# Zip_Code                                      6661
# County                                        6661
# Hospital Adult and Peds Staffed Beds          6661
# Hospital Adult and Peds Bed Days Available    6661
# Hospital Adult and Peds Inpatient Days        6661
# Intensive Care Unit Staffed Beds              6661
# Intensive Care Unit Bed Days Available        6661
# Intensive Care Unit Inpatient Days            6661
# Coronary Care Unit Staffed Beds               6661
# Coronary Care Unit Bed Days Available         6661
# Coronary Care Unit Inpatient Days             6661
# Burn ICU Staffed Beds                         6661
# Burn ICU Bed Days Available                   6661
# Burn ICU Inpatient Days                       6661
# Surgical ICU Staffed Beds                     6661
# Surgical ICU Bed Days Available               6661
# Surgical ICU Inpatient Days                   6661
# Total Staffed Beds                            6661
# Total Bed Days Available                      6661
# Total Inpatient Days                          6661
# ICU Total Staffed Beds                        6661
# ICU Total Bed Days Available                  6661
# ICU Total Inpatient Days                      6661
# ICU Occupancy Rate                            3987
# Total Bed Occupancy Rate                      6618
# geometry                                      6661
# dtype: int64

# %%
hifld_gdf.columns
# Out:
# Index(['X', 'Y', 'OBJECTID', 'ID', 'NAME', 'ADDRESS', 'CITY', 'STATE', 'ZIP',
#        'ZIP4', 'TELEPHONE', 'TYPE', 'STATUS', 'POPULATION', 'COUNTY',
#        'COUNTYFIPS', 'COUNTRY', 'LATITUDE', 'LONGITUDE', 'NAICS_CODE',
#        'NAICS_DESC', 'SOURCE', 'SOURCEDATE', 'VAL_METHOD', 'VAL_DATE',
#        'WEBSITE', 'STATE_ID', 'ALT_NAME', 'ST_FIPS', 'OWNER', 'TTL_STAFF',
#        'BEDS', 'TRAUMA', 'HELIPAD', 'geometry'],
#       dtype='object')

# %%
hifld_gdf[hifld_gdf['ADDRESS'].isnull()]
# Out:
# Empty GeoDataFrame
# Columns: [X, Y, OBJECTID, ID, NAME, ADDRESS, CITY, STATE, ZIP, ZIP4, TELEPHONE, TYPE, STATUS, POPULATION, COUNTY, COUNTYFIPS, COUNTRY, LATITUDE, LONGITUDE, NAICS_CODE, NAICS_DESC, SOURCE, SOURCEDATE, VAL_METHOD, VAL_DATE, WEBSITE, STATE_ID, ALT_NAME, ST_FIPS, OWNER, TTL_STAFF, BEDS, TRAUMA, HELIPAD, geometry]
# Index: []
#
# [0 rows x 35 columns]

# %%
hifld_gdf.count()
# Out:
# X             7581
# Y             7581
# OBJECTID      7581
# ID            7581
# NAME          7581
# ADDRESS       7581
# CITY          7581
# STATE         7581
# ZIP           7581
# ZIP4          7581
# TELEPHONE     7581
# TYPE          7581
# STATUS        7581
# POPULATION    7581
# COUNTY        7581
# COUNTYFIPS    7581
# COUNTRY       7581
# LATITUDE      7581
# LONGITUDE     7581
# NAICS_CODE    7581
# NAICS_DESC    7581
# SOURCE        7581
# SOURCEDATE    7581
# VAL_METHOD    7581
# VAL_DATE      7581
# WEBSITE       7581
# STATE_ID      7581
# ALT_NAME      7581
# ST_FIPS       7581
# OWNER         7581
# TTL_STAFF     7581
# BEDS          7581
# TRAUMA        7581
# HELIPAD       7581
# geometry      7581
# dtype: int64

# %%
dh_gdf.count()
# Out:
# OBJECTID      6580
# HOSPITAL_N    6580
# HOSPITAL_T    6580
# HQ_ADDRESS    6580
# HQ_ADDRE_1     365
# HQ_CITY       6580
# HQ_STATE      6580
# HQ_ZIP_COD    6580
# COUNTY_NAM    6556
# STATE_NAME    6556
# STATE_FIPS    6556
# CNTY_FIPS     6556
# FIPS          6556
# NUM_LICENS    6360
# NUM_STAFFE    6329
# NUM_ICU_BE    2978
# BED_UTILIZ    5906
# Potential_    6580
# geometry      6563
# dtype: int64

# %%
len(dh_gdf['OBJECTID'].values), len(set(dh_gdf['OBJECTID'].values))
# Out:
# (6580, 6580)

# %%
dh_gdf['HOSPITAL_N']
# Out:
# 0                               Trios Southridge Hospital
# 1       Kadlec Regional Medical Center (AKA Kadlec Hea...
# 2                             Central Washington Hospital
# 3                               Wenatchee Valley Hospital
# 4                          Lake Chelan Community Hospital
#                               ...
# 6575    Cirby Hills Behavioral Hospital (FKA Telecare ...
# 6576                                          The Meadows
# 6577            The Menninger Clinic Psychiatric Hospital
# 6578                             The Orthopedic Institute
# 6579             Treasure Coast Forensic Treatment Center
# Name: HOSPITAL_N, Length: 6580, dtype: object

# %%
import math
math.isnan('adf')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-2d7ac6cf5454> in <module>
#       1 import math
# ----> 2 math.isnan('adf')
#
# TypeError: must be real number, not str

# %%
dh_gdf[dh_gdf['geometry'].isna()]
# Out:
#       OBJECTID                                         HOSPITAL_N  \
# 274       4275  Bayamon Medical Center (FKA Hospital Hermanos ...
# 281       4282                     Cayey Mennonite Medical Center
# 283       4284  Mennonite Hospital Guayama (FKA Episcopal Hosp...
# 290       4291                                     Hospital Perea
# 291       4292  Mayaguez Medical Center (AKA Centro Medico De ...
# 295       4296               Hospital Oncologico Andres Grillasca
# 307       4308                             Hospital San Francisco
# 308       4309                             Hospital Metropolitano
# 843       4844  Encompass Health Rehabilitation Hospital of Sa...
# 5027      6028                   Professional Hospital - Guaynabo
# 5382      6383  Hospital Oncológico (AKA Liga Puertorriqueña C...
# 5416      6417                   Doctors Center Hospital Carolina
# 5443      6444                            CIMA Mennonite Hospital
# 5570      6571                 Comprehensive Cancer Center of UPR
# 5572      6573                     San Juan Pan American Hospital
# 5930      5351  Encompass Health Rehabilitation Hospital of Ma...
# 6558      5979              San Jorge Childrens & Womens Hospital
#
#                           HOSPITAL_T  \
# 274   Short Term Acute Care Hospital
# 281   Short Term Acute Care Hospital
# 283   Short Term Acute Care Hospital
# 290   Short Term Acute Care Hospital
# 291   Short Term Acute Care Hospital
# 295   Short Term Acute Care Hospital
# 307   Short Term Acute Care Hospital
# 308   Short Term Acute Care Hospital
# 843          Rehabilitation Hospital
# 5027  Short Term Acute Care Hospital
# 5382  Short Term Acute Care Hospital
# 5416  Short Term Acute Care Hospital
# 5443  Short Term Acute Care Hospital
# 5570  Short Term Acute Care Hospital
# 5572  Short Term Acute Care Hospital
# 5930         Rehabilitation Hospital
# 6558  Short Term Acute Care Hospital
#
#                                              HQ_ADDRESS  \
# 274                                        KM 11 7 PR-2
# 281   Carretera 14 Interior Km. 0.3 Barrio Rincón Se...
# 283                     Calle Principal Urb La Hacienda
# 290                              15 Calle Doctor Basora
# 291                                      410 Ave Hostos
# 295                               1000 Tito Castro Blvd
# 307                             371 Calle José de Diego
# 308                        Carretera 21 #1785 Las Lomas
# 843                                       Centro Medico
# 5027                                Avenida Las Cumbres
# 5382                                Ave Americo Miranda
# 5416                                    Calle Molinillo
# 5443  Calle Sargento Gerardo Santiago Interior 15 Ca...
# 5570               PR 21 INT PR 18 BO Monacillos Urbano
# 5572                          735 Av Juan Ponce de Leon
# 5930                                    Calle 2 Km 47.7
# 6558                                258 Calle San Jorge
#
#                    HQ_ADDRE_1   HQ_CITY HQ_STATE HQ_ZIP_COD COUNTY_NAM  \
# 274                      None   Bayamon       PR        960       None
# 281                      None     Cayey       PR        737       None
# 283                      None   Guayama       PR        785       None
# 290                      None  Mayaguez       PR        681       None
# 291                      None  Mayaguez       PR        681       None
# 295                      None     Ponce       PR        733       None
# 307                      None  San Juan       PR        923       None
# 308                      None  San Juan       PR        922       None
# 843                 3rd Floor  San Juan       PR        921       None
# 5027                     None  Guaynabo       PR        969       None
# 5382         Bo Monacillo 150  San Juan       PR        919       None
# 5416  Jesus T Pinero Building  Carolina       PR        988       None
# 5443                     None   Comerio       PR        782       None
# 5570                     None  San Juan       PR        927       None
# 5572                     None  San Juan       PR        926       None
# 5930                     None    Manati       PR        674       None
# 6558                     None  San Juan       PR        912       None
#
#      STATE_NAME STATE_FIPS CNTY_FIPS  FIPS  NUM_LICENS  NUM_STAFFE  \
# 274        None       None      None  None       253.0       253.0
# 281        None       None      None  None       225.0       225.0
# 283        None       None      None  None       116.0       116.0
# 290        None       None      None  None       118.0       118.0
# 291        None       None      None  None       192.0       192.0
# 295        None       None      None  None        86.0        86.0
# 307        None       None      None  None       125.0       125.0
# 308        None       None      None  None       132.0       132.0
# 843        None       None      None  None        32.0        32.0
# 5027       None       None      None  None        49.0        49.0
# 5382       None       None      None  None        57.0        57.0
# 5416       None       None      None  None       109.0       109.0
# 5443       None       None      None  None         NaN         NaN
# 5570       None       None      None  None         NaN         NaN
# 5572       None       None      None  None         NaN         NaN
# 5930       None       None      None  None        40.0        40.0
# 6558       None       None      None  None       151.0       151.0
#
#       NUM_ICU_BE  BED_UTILIZ  Potential_ geometry
# 274         21.0    0.304586           0     None
# 281         35.0    0.632925           0     None
# 283          6.0    0.634247           0     None
# 290          4.0    0.684397           0     None
# 291         31.0    0.638870           0     None
# 295          NaN         NaN           0     None
# 307         10.0    0.719123           0     None
# 308          6.0    0.527003           0     None
# 843          NaN    0.979281           0     None
# 5027         NaN    0.137266           0     None
# 5382         5.0    0.452824           0     None
# 5416         6.0    0.694407           0     None
# 5443         NaN         NaN           0     None
# 5570         NaN         NaN           0     None
# 5572         NaN         NaN           0     None
# 5930         NaN    0.874452           0     None
# 6558         NaN         NaN           0     None

# %%
# !pip install FuzzyWuzzy
# Out:
# Collecting FuzzyWuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: FuzzyWuzzy
# Successfully installed FuzzyWuzzy-0.18.0

# %%
# !pip install python-Levenshtein
# Out:
# Collecting python-Levenshtein
#   Downloading python-Levenshtein-0.12.0.tar.gz (48 kB)
#      |████████████████████████████████| 48 kB 2.3 MB/s eta 0:00:01
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/site-packages (from python-Levenshtein) (45.2.0)
# Building wheels for collected packages: python-Levenshtein
#   Building wheel for python-Levenshtein (setup.py) ... done
#   Created wheel for python-Levenshtein: filename=python_Levenshtein-0.12.0-cp38-cp38-linux_x86_64.whl size=179488 sha256=fc4882cfb52cf1869d8af7eba2b94f86acf3b54aad6df18ed679a61a8221bed7
#   Stored in directory: /root/.cache/pip/wheels/a8/da/22/2970e270912ba623ccac7d516b7411a820c8f2b4252463a605
# Successfully built python-Levenshtein
# Installing collected packages: python-Levenshtein
# Successfully installed python-Levenshtein-0.12.0
